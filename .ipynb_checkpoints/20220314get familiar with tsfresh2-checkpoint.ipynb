# %%
from tsfresh_feature_extraction import*

# %%
import tsfresh
from tsfresh import feature_selection
from tsfresh import extract_features, select_features

# %%
test_extracted_features = extract_features(df_test,
                                              column_id="Unit",
                                              column_sort="Time",
                                             default_fc_parameters =EfficientFCParameters())
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 40/40 [00:17<00:00,  2.27it/s]

# %%
mode=pd.Series(test_label.T[0])
mode.index+=1

# %%
#RUL
path = DATA_PATH+'RUL.csv'
RUL_frame = pd.read_csv(path, header=None)
RUL = RUL_frame.values[:, 0]
RUL_y=pd.Series(RUL)
RUL_y.index+=1

# %%
p_values=tsfresh.feature_selection.relevance.calculate_relevance_table(impute(test_extracted_features), 
                                                                       RUL_y,ml_task="regression",fdr_level=1e-10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tsfresh\utilities\dataframe_functions.py:198: RuntimeWarning: The columns ['T24__query_similarity_count__query_None__threshold_0.0'
#  'T30__query_similarity_count__query_None__threshold_0.0'
#  'T50__query_similarity_count__query_None__threshold_0.0'
#  'P30__query_similarity_count__query_None__threshold_0.0'
#  'Nf__query_similarity_count__query_None__threshold_0.0'
#  'Nc__query_similarity_count__query_None__threshold_0.0'
#  'Ps30__query_similarity_count__query_None__threshold_0.0'
#  'phi__query_similarity_count__query_None__threshold_0.0'
#  'NRf__query_similarity_count__query_None__threshold_0.0'
#  'NRc__query_similarity_count__query_None__threshold_0.0'
#  'BPR__query_similarity_count__query_None__threshold_0.0'
#  'htBleed__friedrich_coefficients__coeff_0__m_3__r_30'
#  'htBleed__friedrich_coefficients__coeff_1__m_3__r_30'
#  'htBleed__friedrich_coefficients__coeff_2__m_3__r_30'
#  'htBleed__friedrich_coefficients__coeff_3__m_3__r_30'
#  'htBleed__max_langevin_fixed_point__m_3__r_30'
#  'htBleed__query_similarity_count__query_None__threshold_0.0'
#  'W31__query_similarity_count__query_None__threshold_0.0'
#  'W32__query_similarity_count__query_None__threshold_0.0'] did not have any finite values. Filling with zeros.
#   warnings.warn(

# %%
p_values_=p_values[abs(p_values["p_value"])<1e-15].reset_index(drop=True)
p_values_
# Out:
#                                                feature  type       p_value  \
# 0                         Ps30__autocorrelation__lag_1  real  2.116047e-24
# 1                 Ps30__partial_autocorrelation__lag_1  real  2.116047e-24
# 2                         Ps30__autocorrelation__lag_3  real  8.082866e-24
# 3                    Ps30__linear_trend__attr_"rvalue"  real  1.391689e-23
# 4                         Ps30__autocorrelation__lag_6  real  1.478038e-23
# ..                                                 ...   ...           ...
# 103  BPR__agg_autocorrelation__f_agg_"mean"__maxlag_40  real  5.937223e-16
# 104                        NRf__autocorrelation__lag_7  real  6.082427e-16
# 105                        NRf__autocorrelation__lag_4  real  6.387138e-16
# 106                        W31__autocorrelation__lag_6  real  8.771063e-16
# 107     htBleed__fft_coefficient__attr_"imag"__coeff_1  real  9.208045e-16
#
#      relevant
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 103      True
# 104      True
# 105      True
# 106      True
# 107      True
#
# [108 rows x 4 columns]

# %%
p_values_mode=tsfresh.feature_selection.relevance.calculate_relevance_table(impute(test_extracted_features), 
                                                                       mode,ml_task='classification', 
                                                                            #fdr_level=1.105
                                                                           )

# %%
p_values_mode_=p_values_mode[abs(p_values_mode["p_value"])<1e-15].reset_index(drop=True)
p_values_mode_
# Out:
#                                               feature  type       p_value  \
# 0   phi__agg_linear_trend__attr_"rvalue"__chunk_le...  real  1.029330e-17
# 1   phi__agg_linear_trend__attr_"rvalue"__chunk_le...  real  1.160850e-17
# 2   P30__agg_linear_trend__attr_"rvalue"__chunk_le...  real  1.160850e-17
# 3                    phi__linear_trend__attr_"rvalue"  real  1.160850e-17
# 4                    P30__linear_trend__attr_"rvalue"  real  1.160850e-17
# ..                                                ...   ...           ...
# 62  BPR__agg_linear_trend__attr_"rvalue"__chunk_le...  real  5.519707e-16
# 63  BPR__agg_linear_trend__attr_"rvalue"__chunk_le...  real  5.843032e-16
# 64  P30__agg_linear_trend__attr_"rvalue"__chunk_le...  real  6.546680e-16
# 65  P30__agg_linear_trend__attr_"slope"__chunk_len...  real  7.333676e-16
# 66  W31__agg_linear_trend__attr_"slope"__chunk_len...  real  9.179561e-16
#
#     relevant
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 62      True
# 63      True
# 64      True
# 65      True
# 66      True
#
# [67 rows x 4 columns]

# %%
selected_columns=np.hstack([p_values_mode_["feature"].values,p_values_["feature"].values])

# %%
X_tsfresh_filter=test_extracted_features.copy()[selected_columns]

# %%
kind_to_fc_parameters_large=tsfresh.feature_extraction.settings.from_columns(X_tsfresh_filter)

# %%
save_dict(kind_to_fc_parameters_large,"./numpy/kind_to_fc_parameters_large")

# %%
kind_to_fc_parameters_large
# Out:
# {'phi': {'agg_linear_trend': [{'attr': 'rvalue',
#     'chunk_len': 5,
#     'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 50, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'slope', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 10, 'f_agg': 'min'},
#    {'attr': 'slope', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'max'},
#    {'attr': 'slope', 'chunk_len': 5, 'f_agg': 'max'}],
#   'linear_trend': [{'attr': 'rvalue'}, {'attr': 'slope'}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1},
#    {'attr': 'imag', 'coeff': 2},
#    {'attr': 'imag', 'coeff': 3},
#    {'attr': 'angle', 'coeff': 1},
#    {'attr': 'imag', 'coeff': 4},
#    {'attr': 'imag', 'coeff': 5},
#    {'attr': 'real', 'coeff': 1}],
#   'first_location_of_maximum': None,
#   'last_location_of_minimum': None,
#   'first_location_of_minimum': None,
#   'last_location_of_maximum': None,
#   'longest_strike_below_mean': None},
#  'P30': {'agg_linear_trend': [{'attr': 'rvalue',
#     'chunk_len': 5,
#     'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 50, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'min'},
#    {'attr': 'slope', 'chunk_len': 10, 'f_agg': 'mean'}],
#   'linear_trend': [{'attr': 'rvalue'}, {'attr': 'slope'}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1},
#    {'attr': 'imag', 'coeff': 2}],
#   'first_location_of_maximum': None,
#   'last_location_of_maximum': None,
#   'longest_strike_below_mean': None},
#  'BPR': {'agg_linear_trend': [{'attr': 'rvalue',
#     'chunk_len': 5,
#     'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'slope', 'chunk_len': 50, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'max'}],
#   'linear_trend': [{'attr': 'rvalue'}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1}],
#   'energy_ratio_by_chunks': [{'num_segments': 10, 'segment_focus': 9}],
#   'autocorrelation': [{'lag': 2}],
#   'index_mass_quantile': [{'q': 0.7}],
#   'agg_autocorrelation': [{'f_agg': 'mean', 'maxlag': 40}]},
#  'W32': {'agg_linear_trend': [{'attr': 'rvalue',
#     'chunk_len': 10,
#     'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'slope', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'slope', 'chunk_len': 50, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'}],
#   'linear_trend': [{'attr': 'rvalue'}, {'attr': 'slope'}, {'attr': 'pvalue'}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1}],
#   'autocorrelation': [{'lag': 7}, {'lag': 8}, {'lag': 6}],
#   'agg_autocorrelation': [{'f_agg': 'mean', 'maxlag': 40},
#    {'f_agg': 'median', 'maxlag': 40}]},
#  'W31': {'linear_trend': [{'attr': 'rvalue'}, {'attr': 'pvalue'}],
#   'agg_linear_trend': [{'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'slope', 'chunk_len': 50, 'f_agg': 'mean'}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1},
#    {'attr': 'imag', 'coeff': 3}],
#   'agg_autocorrelation': [{'f_agg': 'median', 'maxlag': 40},
#    {'f_agg': 'mean', 'maxlag': 40}],
#   'autocorrelation': [{'lag': 3}, {'lag': 9}, {'lag': 2}, {'lag': 6}]},
#  'Ps30': {'autocorrelation': [{'lag': 1},
#    {'lag': 3},
#    {'lag': 6},
#    {'lag': 2},
#    {'lag': 4},
#    {'lag': 9},
#    {'lag': 5},
#    {'lag': 8},
#    {'lag': 7}],
#   'partial_autocorrelation': [{'lag': 1}, {'lag': 2}],
#   'linear_trend': [{'attr': 'rvalue'}, {'attr': 'pvalue'}],
#   'agg_autocorrelation': [{'f_agg': 'median', 'maxlag': 40},
#    {'f_agg': 'mean', 'maxlag': 40}],
#   'agg_linear_trend': [{'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'}],
#   'maximum': None,
#   'time_reversal_asymmetry_statistic': [{'lag': 3}, {'lag': 2}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1}],
#   'energy_ratio_by_chunks': [{'num_segments': 10, 'segment_focus': 9}],
#   'longest_strike_above_mean': None,
#   'index_mass_quantile': [{'q': 0.8}, {'q': 0.6}],
#   'augmented_dickey_fuller': [{'attr': 'pvalue', 'autolag': 'AIC'},
#    {'attr': 'teststat', 'autolag': 'AIC'}],
#   'mean_n_absolute_max': [{'number_of_maxima': 7}]},
#  'T24': {'linear_trend': [{'attr': 'rvalue'}, {'attr': 'pvalue'}],
#   'agg_autocorrelation': [{'f_agg': 'mean', 'maxlag': 40},
#    {'f_agg': 'median', 'maxlag': 40}],
#   'agg_linear_trend': [{'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'min'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'}],
#   'partial_autocorrelation': [{'lag': 1}],
#   'autocorrelation': [{'lag': 1}],
#   'longest_strike_above_mean': None},
#  'T50': {'autocorrelation': [{'lag': 6},
#    {'lag': 2},
#    {'lag': 7},
#    {'lag': 1},
#    {'lag': 4},
#    {'lag': 9},
#    {'lag': 3},
#    {'lag': 5},
#    {'lag': 8}],
#   'agg_autocorrelation': [{'f_agg': 'median', 'maxlag': 40},
#    {'f_agg': 'mean', 'maxlag': 40}],
#   'linear_trend': [{'attr': 'rvalue'}, {'attr': 'pvalue'}],
#   'partial_autocorrelation': [{'lag': 1}, {'lag': 2}],
#   'agg_linear_trend': [{'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'}],
#   'longest_strike_below_mean': None,
#   'energy_ratio_by_chunks': [{'num_segments': 10, 'segment_focus': 9}],
#   'index_mass_quantile': [{'q': 0.7}],
#   'longest_strike_above_mean': None,
#   'augmented_dickey_fuller': [{'attr': 'teststat', 'autolag': 'AIC'},
#    {'attr': 'pvalue', 'autolag': 'AIC'}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1}]},
#  'htBleed': {'linear_trend': [{'attr': 'rvalue'}, {'attr': 'pvalue'}],
#   'agg_linear_trend': [{'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 10, 'f_agg': 'max'}],
#   'agg_autocorrelation': [{'f_agg': 'median', 'maxlag': 40},
#    {'f_agg': 'mean', 'maxlag': 40}],
#   'autocorrelation': [{'lag': 7}, {'lag': 1}, {'lag': 4}],
#   'partial_autocorrelation': [{'lag': 1}],
#   'fft_coefficient': [{'attr': 'imag', 'coeff': 1}]},
#  'T30': {'linear_trend': [{'attr': 'rvalue'}, {'attr': 'pvalue'}],
#   'agg_autocorrelation': [{'f_agg': 'mean', 'maxlag': 40},
#    {'f_agg': 'median', 'maxlag': 40}],
#   'agg_linear_trend': [{'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'mean'},
#    {'attr': 'rvalue', 'chunk_len': 5, 'f_agg': 'max'}]},
#  'Nf': {'agg_autocorrelation': [{'f_agg': 'mean', 'maxlag': 40},
#    {'f_agg': 'median', 'maxlag': 40}]},
#  'NRf': {'autocorrelation': [{'lag': 7}, {'lag': 4}]}}

# %%
kind_to_fc_parameters=load_dict("./numpy/kind_to_fc_parameters_new")
dataframe_list=[]
for idx in range(len(train_dataset_expend)):
    dataframe_list.append(get_dataframe_ofcuttedsequence(train_dataset_expend,idx))
train_dataset_expend_dataframe=pd.concat(dataframe_list).reset_index(drop=True)
train_dataset_expend_dataframe.to_csv("./numpy/train_dataset_expend_dataframe.csv")
extracted_features_enhanced = extract_features(train_dataset_expend_dataframe,
                                              column_id="Unit",
                                              column_sort="Time",
                                             kind_to_fc_parameters =kind_to_fc_parameters_new)
extracted_features_enhanced=impute(extracted_features_enhanced)
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 40/40 [00:40<00:00,  1.00s/it]

# %%
extracted_features_enhanced
# Out:
#        T24__linear_trend__attr_"rvalue"  T24__linear_trend__attr_"pvalue"  \
# 1                             -0.114404                      8.070508e-01
# 2                             -0.080631                      8.494713e-01
# 3                             -0.402781                      2.824535e-01
# 4                             -0.260787                      4.667686e-01
# 5                             -0.203971                      5.474545e-01
# ...                                 ...                               ...
# 24016                          0.442864                      1.944852e-08
# 24017                          0.453962                      6.838982e-09
# 24018                          0.459206                      3.851654e-09
# 24019                          0.470134                      1.279074e-09
# 24020                          0.481337                      3.942436e-10
#
#        T24__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 1                                              -0.084581
# 2                                              -0.076223
# 3                                              -0.185267
# 4                                              -0.084126
# 5                                              -0.064347
# ...                                                  ...
# 24016                                           0.124021
# 24017                                           0.131344
# 24018                                           0.136145
# 24019                                           0.143517
# 24020                                           0.151184
#
#        T24__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 1                                              -0.027152
# 2                                              -0.014635
# 3                                              -0.268447
# 4                                              -0.175125
# 5                                              -0.048067
# ...                                                  ...
# 24016                                           0.135736
# 24017                                           0.143643
# 24018                                           0.143397
# 24019                                           0.156329
# 24020                                           0.163179
#
#        T24__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean"  \
# 1                                               1.000000
# 2                                               1.000000
# 3                                              -1.000000
# 4                                              -1.000000
# 5                                               0.239275
# ...                                                  ...
# 24016                                           0.687703
# 24017                                           0.689307
# 24018                                           0.687607
# 24019                                           0.688878
# 24020                                           0.723585
#
#        T30__linear_trend__attr_"rvalue"  \
# 1                              0.481485
# 2                              0.635565
# 3                              0.694879
# 4                              0.709448
# 5                              0.307358
# ...                                 ...
# 24016                          0.549488
# 24017                          0.552166
# 24018                          0.555220
# 24019                          0.564744
# 24020                          0.568742
#
#        T30__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 1                                              -0.202694
# 2                                              -0.331511
# 3                                              -0.351809
# 4                                              -0.339781
# 5                                              -0.002406
# ...                                                  ...
# 24016                                           0.208155
# 24017                                           0.212981
# 24018                                           0.218111
# 24019                                           0.226970
# 24020                                           0.233020
#
#        T30__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 1                                              -0.125619
# 2                                              -0.266627
# 3                                              -0.227305
# 4                                              -0.104984
# 5                                              -0.057861
# ...                                                  ...
# 24016                                           0.211505
# 24017                                           0.216284
# 24018                                           0.223477
# 24019                                           0.228645
# 24020                                           0.238538
#
#        T50__autocorrelation__lag_6  T50__autocorrelation__lag_2  ...  \
# 1                        -0.236307                    -0.209407  ...
# 2                        -0.086759                    -0.221833  ...
# 3                         0.641854                    -0.019556  ...
# 4                         0.106930                    -0.054927  ...
# 5                         0.137605                    -0.309531  ...
# ...                            ...                          ...  ...
# 24016                     0.481309                     0.489057  ...
# 24017                     0.489006                     0.493188  ...
# 24018                     0.492245                     0.501488  ...
# 24019                     0.504975                     0.507712  ...
# 24020                     0.511437                     0.519707  ...
#
#        phi__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"  \
# 1                                              -1.000000
# 2                                              -1.000000
# 3                                              -1.000000
# 4                                              -1.000000
# 5                                              -0.992386
# ...                                                  ...
# 24016                                          -0.869901
# 24017                                          -0.869901
# 24018                                          -0.869901
# 24019                                          -0.869901
# 24020                                          -0.882874
#
#        phi__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"mean"  \
# 1                                               0.066630
# 2                                              -0.051296
# 3                                              -0.163321
# 4                                              -0.211219
# 5                                              -0.083144
# ...                                                  ...
# 24016                                          -0.028743
# 24017                                          -0.028928
# 24018                                          -0.028882
# 24019                                          -0.029055
# 24020                                          -0.029590
#
#        phi__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"  \
# 1                                               0.012597
# 2                                               0.012597
# 3                                               0.012597
# 4                                               0.012597
# 5                                               0.333110
# ...                                                  ...
# 24016                                          -0.047381
# 24017                                          -0.048216
# 24018                                          -0.048216
# 24019                                          -0.049956
# 24020                                          -0.046551
#
#        phi__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"min"  \
# 1                                               0.388332
# 2                                               0.059500
# 3                                              -0.152750
# 4                                              -0.152750
# 5                                               0.090180
# ...                                                  ...
# 24016                                          -0.023191
# 24017                                          -0.023539
# 24018                                          -0.023539
# 24019                                          -0.023988
# 24020                                          -0.023698
#
#        phi__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"max"  \
# 1                                              -0.047733
# 2                                              -0.047733
# 3                                              -0.047733
# 4                                              -0.047733
# 5                                              -1.000000
# ...                                                  ...
# 24016                                          -0.931628
# 24017                                          -0.931628
# 24018                                          -0.931628
# 24019                                          -0.931628
# 24020                                          -0.941590
#
#        phi__linear_trend__attr_"rvalue"  phi__linear_trend__attr_"slope"  \
# 1                              0.455547                         0.040406
# 2                              0.016756                         0.001422
# 3                             -0.337324                        -0.031016
# 4                             -0.473591                        -0.040569
# 5                             -0.446089                        -0.033185
# ...                                 ...                              ...
# 24016                         -0.751222                        -0.005618
# 24017                         -0.756944                        -0.005688
# 24018                         -0.761996                        -0.005731
# 24019                         -0.767443                        -0.005812
# 24020                         -0.771748                        -0.005838
#
#        phi__fft_coefficient__attr_"imag"__coeff_1  \
# 1                                        0.472920
# 2                                        0.142761
# 3                                       -0.397137
# 4                                       -0.901872
# 5                                       -1.185293
# ...                                           ...
# 24016                                  -19.065375
# 24017                                  -19.499331
# 24018                                  -19.938840
# 24019                                  -20.389935
# 24020                                  -20.844056
#
#        phi__fft_coefficient__attr_"imag"__coeff_2  \
# 1                                       -0.219525
# 2                                       -0.239815
# 3                                       -0.339460
# 4                                       -0.108455
# 5                                        0.458714
# ...                                           ...
# 24016                                   -7.629479
# 24017                                   -7.795632
# 24018                                   -7.969764
# 24019                                   -8.163599
# 24020                                   -8.359640
#
#        phi__fft_coefficient__attr_"imag"__coeff_3
# 1                                       -0.157668
# 2                                       -0.733689
# 3                                       -0.707621
# 4                                       -0.245808
# 5                                        0.125999
# ...                                           ...
# 24016                                   -8.412231
# 24017                                   -8.663859
# 24018                                   -8.912749
# 24019                                   -9.175810
# 24020                                   -9.426124
#
# [24020 rows x 58 columns]

# %%
# pca = PCA(30,whiten=True)  
# extracted_features_PCA=pca.fit_transform(extracted_features_enhanced.values)

# %%
# extracted_features_PCA.shape
# Out:
# (24020, 30)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# np.save("./numpy/extracted_features_PCA.npy",extracted_features_PCA)

# %%
dataframe_test_list = []
for idx in range(len(test_dataset)):
    dataframe_test_list.append(get_dataframe_ofcuttedsequence(test_dataset, idx))
test_dataset_dataframe = pd.concat(dataframe_test_list).reset_index(drop=True)
test_dataset_dataframe.to_csv("./numpy/test_dataset_dataframe.csv")
  # test_dataset_dataframe = pd.read_csv("./numpy/test_dataset_dataframe.csv")
  # test_dataset_dataframe = test_dataset_dataframe.drop(["Unnamed: 0"], axis=1)
test_extracted_features = extract_features(test_dataset_dataframe,
                                             column_id="Unit",
                                             column_sort="Time",
                                             kind_to_fc_parameters=kind_to_fc_parameters_new)
test_extracted_features = impute(test_extracted_features)
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 40/40 [00:03<00:00, 10.91it/s]

# %%
test_extracted_features
# Out:
#      T24__linear_trend__attr_"rvalue"  T24__linear_trend__attr_"pvalue"  \
# 1                            0.388249                      8.413180e-10
# 2                            0.355822                      4.998625e-05
# 3                            0.360613                      1.354817e-08
# 4                            0.184190                      1.326834e-01
# 5                           -0.145894                      8.774380e-02
# ..                                ...                               ...
# 96                           0.197795                      1.654558e-04
# 97                           0.139722                      1.768712e-01
# 98                           0.395764                      3.205713e-08
# 99                           0.624870                      1.052298e-32
# 100                          0.270782                      1.596244e-05
#
#      T24__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 1                                             0.138396
# 2                                             0.051988
# 3                                             0.091699
# 4                                            -0.023344
# 5                                            -0.001195
# ..                                                 ...
# 96                                            0.021643
# 97                                           -0.010881
# 98                                            0.122635
# 99                                            0.337947
# 100                                           0.202323
#
#      T24__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 1                                             0.140898
# 2                                             0.065124
# 3                                             0.091069
# 4                                            -0.011677
# 5                                            -0.002324
# ..                                                 ...
# 96                                            0.026924
# 97                                            0.005062
# 98                                            0.124754
# 99                                            0.336884
# 100                                           0.208987
#
#      T24__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean"  \
# 1                                             0.695748
# 2                                             0.617970
# 3                                             0.660046
# 4                                             0.323654
# 5                                            -0.277925
# ..                                                 ...
# 96                                            0.394296
# 97                                            0.323303
# 98                                            0.642557
# 99                                            0.890682
# 100                                           0.428960
#
#      T30__linear_trend__attr_"rvalue"  \
# 1                            0.414369
# 2                            0.269475
# 3                            0.471976
# 4                           -0.128439
# 5                            0.124686
# ..                                ...
# 96                           0.275612
# 97                           0.283999
# 98                           0.430540
# 99                           0.559940
# 100                          0.538033
#
#      T30__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 1                                             0.154352
# 2                                             0.042870
# 3                                             0.192789
# 4                                            -0.023834
# 5                                             0.009567
# ..                                                 ...
# 96                                            0.066002
# 97                                            0.033830
# 98                                            0.120649
# 99                                            0.337278
# 100                                           0.265687
#
#      T30__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 1                                             0.153724
# 2                                             0.034768
# 3                                             0.192268
# 4                                            -0.015224
# 5                                             0.017143
# ..                                                 ...
# 96                                            0.067940
# 97                                            0.045373
# 98                                            0.119660
# 99                                            0.345947
# 100                                           0.266597
#
#      T50__autocorrelation__lag_6  T50__autocorrelation__lag_2  ...  \
# 1                       0.316503                     0.296809  ...
# 2                       0.224910                     0.312316  ...
# 3                       0.433844                     0.435006  ...
# 4                       0.025066                    -0.056008  ...
# 5                       0.081366                     0.186006  ...
# ..                           ...                          ...  ...
# 96                      0.152027                     0.155288  ...
# 97                      0.042679                    -0.088466  ...
# 98                      0.399952                     0.398590  ...
# 99                      0.562203                     0.588080  ...
# 100                     0.338594                     0.383988  ...
#
#      phi__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"  \
# 1                                             0.921971
# 2                                            -0.574131
# 3                                             0.890089
# 4                                            -0.441579
# 5                                             0.871958
# ..                                                 ...
# 96                                            0.820438
# 97                                           -0.313352
# 98                                           -0.812498
# 99                                            0.928684
# 100                                           0.941482
#
#      phi__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"mean"  \
# 1                                             0.022321
# 2                                            -0.023034
# 3                                             0.016213
# 4                                            -0.037708
# 5                                             0.033790
# ..                                                 ...
# 96                                            0.004794
# 97                                           -0.004677
# 98                                           -0.017535
# 99                                            0.029468
# 100                                           0.039030
#
#      phi__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"  \
# 1                                             0.053689
# 2                                            -0.037036
# 3                                             0.038781
# 4                                            -0.003884
# 5                                             0.080873
# ..                                                 ...
# 96                                            0.010431
# 97                                           -0.016404
# 98                                           -0.028191
# 99                                            0.067445
# 100                                           0.099339
#
#      phi__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"min"  \
# 1                                             0.025755
# 2                                            -0.021051
# 3                                             0.017603
# 4                                            -0.019498
# 5                                             0.040510
# ..                                                 ...
# 96                                            0.005249
# 97                                           -0.008652
# 98                                           -0.015570
# 99                                            0.032907
# 100                                           0.045889
#
#      phi__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"max"  \
# 1                                             0.928841
# 2                                            -0.700019
# 3                                             0.897268
# 4                                            -0.540909
# 5                                             0.877478
# ..                                                 ...
# 96                                            0.835349
# 97                                           -0.738130
# 98                                           -0.834861
# 99                                            0.926756
# 100                                           0.950724
#
#      phi__linear_trend__attr_"rvalue"  phi__linear_trend__attr_"slope"  \
# 1                            0.896057                         0.004408
# 2                           -0.545110                        -0.004563
# 3                            0.882393                         0.003215
# 4                           -0.451682                        -0.007614
# 5                            0.723742                         0.006634
# ..                                ...                              ...
# 96                           0.797922                         0.000947
# 97                          -0.217785                        -0.000873
# 98                          -0.625469                        -0.003492
# 99                           0.919654                         0.005867
# 100                          0.923395                         0.007753
#
#      phi__fft_coefficient__attr_"imag"__coeff_1  \
# 1                                     37.457871
# 2                                     -9.027955
# 3                                     26.286757
# 4                                     -4.727212
# 5                                     21.105526
# ..                                          ...
# 96                                    17.221667
# 97                                    -1.439282
# 98                                   -16.108948
# 99                                    77.375807
# 100                                   73.180381
#
#      phi__fft_coefficient__attr_"imag"__coeff_2  \
# 1                                     19.585048
# 2                                     -8.279116
# 3                                     15.226066
# 4                                     -3.718405
# 5                                     10.848361
# ..                                          ...
# 96                                    11.153662
# 97                                     0.136229
# 98                                    -9.527136
# 99                                    39.350081
# 100                                   43.340337
#
#      phi__fft_coefficient__attr_"imag"__coeff_3
# 1                                     12.726073
# 2                                     -6.773519
# 3                                      9.707284
# 4                                     -0.807619
# 5                                      5.087124
# ..                                          ...
# 96                                     6.917025
# 97                                    -0.571232
# 98                                   -12.617962
# 99                                    25.546061
# 100                                   26.121475
#
# [100 rows x 58 columns]

# %%
# test_feature_PCA=pca.transform(test_extracted_features.values)
# np.save("./numpy/test_feature_PCA.npy", test_feature_PCA)

# %%
# test_feature_PCA.shape

# %%
scaler = MinMaxScaler((-1,1))

# %%
features_extracted_minmax=scaler.fit_transform(np.vstack([extracted_features_enhanced.values,
                                                          test_extracted_features.values]))

# %%
features_extracted_minmax.shape
# Out:
# (24120, 58)

# %%
train_extracted_minmax,test_extracted_minmax=np.vsplit(features_extracted_minmax,np.array([24020]))

# %%
train_extracted_minmax.shape
# Out:
# (24020, 58)

# %%
np.save("./numpy/train_extracted_minmax.npy", train_extracted_minmax)
np.save("./numpy/test_extracted_minmax.npy", test_extracted_minmax)
