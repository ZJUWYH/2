# %%
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset
from tqdm.notebook import tqdm
from collections import Counter
import torch.nn as nn
import gc
import time
import torch
import numpy as np
from torch.utils.data import DataLoader
from transformers import get_linear_schedule_with_warmup

# %%
class Preprocessing:

    def drop_sensors(df,sensor_index):
        df0=df.copy()
        df0.drop(df0.columns[sensor_index],axis=1,inplace=True)
        return df0

    def drop_units(df,unit_index):
        df0=df.copy()
        df0.drop(df0[df0[df0.columns[0]].isin(unit_index)].index,axis=0,inplace=True)
        return df0.reset_index(drop=True)


    def add_timeseries(df):
        df0 = df.copy()
        df0["Time"] = df0.groupby(["Unit"]).cumcount() + 1
        return df0

# %%
class CFG:
    seed=42
    input_dim=14
    input_feature=42
    num_worker=4
    hidden_size=64
    batch_size=1
    num_classes=1
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    optimizer="Adam"
    lr=1e-2
    epoches=10000
    kernel=True
    print_training_process=True

import random
def seed_everything(seed):
    """
    Seeds basic parameters for reproductibility of results.

    Args:
        seed (int): Number of the seed.
    """
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
import torch.nn as nn

seed_everything(CFG.seed)

# %%
DATA_PATH = "./Data_FD003/preprocessed data/"

attribute = ['Unit', 'T24','T30','T50','P30','Nf','Nc','Ps30',
                      'phi','NRf','NRc','BPR','htBleed','W31','W32']

df_train = pd.read_csv(DATA_PATH + 'TD_data.csv',names=attribute, header=None)
df_test = pd.read_csv(DATA_PATH + 'Test_data.csv',names=attribute, header=None)

#df_=Preprocessing.add_timeseries(df_)
df_train=Preprocessing.add_timeseries(df_train)
df_test=Preprocessing.add_timeseries(df_test)

small_train=df_train[df_train['Unit'] < 10].reset_index(drop=True)
small_test=df_test[df_test['Unit'] < 5].reset_index(drop=True)

# %%
class AircraftDataset(Dataset):
    def __init__(self, df):
        self.df = df.groupby("Unit").agg(list).reset_index()

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, idx):
        data = {}
        sensor = ['T24','T30','T50','P30','Nf','Nc','Ps30',
                      'phi','NRf','NRc','BPR','htBleed','W31','W32']
        multi_sensor = []
        for sensor_name in sensor:
            multi_sensor.append(np.array(self.df[sensor_name].values.tolist()[idx]))
            single_sensor = np.array(self.df[sensor_name].values.tolist()[idx])[:, None]
            data[sensor_name] = torch.tensor(single_sensor, dtype=torch.float)
        multi_sensor = np.vstack(multi_sensor).transpose(1, 0)
        data["input"] = torch.tensor(multi_sensor, dtype=torch.float)
        data["lifetime"] = torch.tensor(len(multi_sensor), dtype=torch.int64)
        data["timeseries"] = torch.tensor(np.array(self.df["Time"].values.tolist()[idx])[:, None], dtype=torch.int64)

        return data

# %%
from diwang_feature_exrtaction import*
# Out:
# C:\Users\Administrator\Documents\yh.wang\2\diwang_feature_exrtaction.py:194: RuntimeWarning: invalid value encountered in true_divide
#   W = Weight / np.tile(reshape(sum(Weight, 2), (Num, TestData.shape[1] - 1, 1)), (1, 1, Nu))

# %%
RUL_delete
# Out:
# array([ 44,  51,  27, 120, 101,  99,  71,  55,  55,  66,  77, 115, 115,
#         31, 108,  56, 136, 132,  85,  56,  18, 119,  78,   9,  58,  11,
#         88, 144, 124,  89,  79,  55,  71,  65,  87, 137, 145,  22,   8,
#         41, 131, 115, 128,  69, 111,   7, 137,  55, 135,  11,  78, 120,
#         87,  87,  55,  93,  88,  40,  49, 128, 129,  58, 117,  28, 115,
#         87,  92, 103, 100,  63,  35,  45,  99, 117,  45,  27,  86,  20,
#         18,  15,   6, 145, 104,  56,  25,  68, 144,  41,  51,  81,  14,
#         67,  10, 127, 123,  17,   8,  28], dtype=int64)

# %%
RUL_train=np.array([int(i) for i in np.ceil(Tal0.reshape(-1)*0.3)],dtype=np.int64)
runtime_train=np.array([int(i) for i in (Tal0.reshape(-1)-RUL_train)],dtype=np.int64)

# %%
RUL_train
# Out:
# array([ 78,  76,  67,  82,  64,  84, 128,  81, 122, 145,  60,  51,  56,
#         63,  61, 104,  94, 135,  69, 102,  66,  58,  59, 149,  58,  73,
#         96,  60,  67,  66,  55,  57,  70, 138,  70,  98,  98,  61,  87,
#         57,  89,  58,  97,  54,  62,  62,  81,  53,  77,  49,  57,  67,
#         50,  59, 158,  59,  65,  54,  90,  57,  60,  74,  70,  59,  71,
#         50,  79,  61,  51,  52, 123,  70,  65,  58,  78,  46,  77,  67,
#         50,  45, 105,  86,  55,  68,  80, 103,  52,  97,  63,  55,  47,
#         48,  52, 118,  50, 148,  83,  93,  44,  46], dtype=int64)

# %%
G[0][runtime_train[0]-1]
# Out:
# array([ 0.1122129 ,  0.08503815,  0.09414901, -0.10680172,  0.08741078,
#        -0.08482459])

# %%
class TrainingFeature(Da)

# %%
class Feature_v1(AircraftDataset):
    def __init__(self,df):
        super().__init__(df)
    def __getitem__(self,idx):
        return super().__getitem__(idx)["input"]

# %%
small_train_=AircraftDataset(df_train)
test=Feature_v1(df_train)
train_loader = DataLoader(
        test,
        batch_size=CFG.batch_size,
        shuffle=False)#train_dataset
for data in train_loader:
    print(data)
# Out:
# tensor([[[ 0.9361,  0.3063,  0.2995,  ...,  0.4386,  0.3644, -0.8462],
#          [ 1.0359,  0.4529,  0.3033,  ...,  0.7510, -0.3053, -0.3649],
#          [ 0.7912,  0.2064,  0.8094,  ...,  0.4386, -0.7561, -0.7919],
#          ...,
#          [ 1.5619,  1.3918,  1.4484,  ...,  1.7102, -1.5759, -1.5357],
#          [ 1.6165,  1.5726,  1.5852,  ...,  1.4801, -1.4152, -1.6131],
#          [ 1.7176,  1.3226,  1.6458,  ...,  1.7102, -1.5873, -1.6039]]])
# tensor([[[ 1.0474,  1.2005,  0.2477,  ...,  1.1000,  0.7744, -0.0445],
#          [ 0.6587,  0.6947,  0.4586,  ...,  0.8903,  0.5717,  0.6227],
#          [ 0.6080,  1.0038,  0.0554,  ...,  1.1000,  0.4837,  0.1423],
#          ...,
#          [ 1.6563,  1.5911,  1.5836,  ...,  1.6636,  1.6871,  1.5290],
#          [ 1.5526,  1.7255,  1.3353,  ...,  1.6636,  1.5384,  1.5525],
#          [ 1.5486,  1.5026,  1.3803,  ...,  1.7659,  1.7143,  1.6716]]])
# tensor([[[ 0.5899,  0.9723,  0.6380,  ...,  0.4386, -0.8364,  0.9203],
#          [ 0.3650,  1.0321,  0.1126,  ...,  0.4386, -0.5939, -0.7893],
#          [ 0.4896,  0.7860,  0.1917,  ...,  0.4386, -0.5310, -0.1747],
#          ...,
#          [ 1.5333,  1.7329,  1.5565,  ...,  1.3415, -1.7066, -1.4296],
#          [ 1.6500,  1.5219,  1.6211,  ...,  1.4801, -1.6230, -1.3527],
#          [ 1.7412,  1.5080,  1.4378,  ...,  1.4801, -1.6657, -1.3635]]])
# tensor([[[-0.8180,  0.7138,  1.4632,  ...,  0.8863, -1.6248, -0.6473],
#          [ 1.0407,  0.7323,  1.4241,  ...,  1.0969, -1.1804, -0.2500],
#          [ 0.3207,  0.7080,  1.4077,  ...,  0.6194, -1.5338, -0.6729],
#          ...,
#          [ 1.2196,  1.4678,  1.7067,  ...,  1.4187, -1.8822, -1.2565],
#          [ 1.3417,  1.3126,  1.7938,  ...,  1.2707, -1.9314, -1.5011],
#          [ 1.2745,  1.2544,  1.7082,  ...,  1.5476, -1.8393, -1.3692]]])
# tensor([[[ 2.1868,  1.4802,  1.0122,  ...,  0.6244, -0.4980, -0.6745],
#          [ 1.9667,  1.3831,  0.7866,  ...,  0.6244, -0.7090, -0.2776],
#          [ 1.9369,  1.2910,  0.6831,  ...,  0.6244, -0.9493, -0.8370],
#          ...,
#          [ 2.2652,  1.7313,  1.7743,  ...,  1.2733, -1.5437, -1.3421],
#          [ 2.1607,  1.6270,  1.5609,  ...,  1.2733, -1.4954, -1.4136],
#          [ 2.2247,  1.9068,  1.7477,  ...,  1.5497, -1.6863, -1.5144]]])
# tensor([[[ 1.0540,  0.4906,  0.1387,  ...,  0.6244, -0.4202, -1.1646],
#          [ 0.5323,  0.2792, -0.2935,  ...,  0.2614, -0.9444, -0.9009],
#          [ 1.1966,  1.1737,  0.3867,  ...,  1.1000, -0.8308, -0.9208],
#          ...,
#          [ 1.7096,  1.4708,  1.5108,  ...,  1.4210, -1.6941, -1.6451],
#          [ 1.7335,  1.6033,  1.4829,  ...,  1.4210, -1.7142, -1.5527],
#          [ 1.7165,  1.4888,  1.4556,  ...,  1.5497, -1.5872, -1.6973]]])
# tensor([[[ 0.8631,  0.7380,  0.4078,  ...,  0.3157, -0.3295, -0.0432],
#          [ 1.2246,  0.7953,  0.4213,  ...,  0.9196,  0.4793,  0.4787],
#          [ 1.0195,  0.4249,  0.2311,  ...,  0.6626,  0.2363,  0.1971],
#          ...,
#          [ 1.6150,  1.5295,  1.4992,  ...,  1.5649,  1.5043,  1.5648],
#          [ 1.5683,  1.5469,  1.6667,  ...,  1.4384,  1.5369,  1.5538],
#          [ 1.2899,  1.7718,  1.6190,  ...,  1.5649,  1.4237,  1.4096]]])
# tensor([[[ 0.5515,  1.2540,  0.8296,  ...,  0.2614, -1.2243, -1.3125],
#          [ 0.9902,  1.4136,  0.9028,  ...,  1.2733, -0.8319, -0.9866],
#          [ 0.4592,  1.1536,  1.0145,  ...,  0.8903, -0.9666, -0.8925],
#          ...,
#          [ 1.1042,  1.6004,  1.4362,  ...,  1.4210, -1.6637, -1.3797],
#          [ 1.5834,  1.6221,  1.7135,  ...,  1.4210, -1.5415, -1.6090],
#          [ 1.3352,  1.5586,  1.4377,  ...,  1.5497, -1.5877, -1.6383]]])
# tensor([[[0.8485, 0.5753, 0.5125,  ..., 1.0969, 0.8218, 0.6669],
#          [0.4397, 0.2905, 0.1306,  ..., 0.8863, 0.6557, 0.2294],
#          [0.9496, 0.5322, 0.6166,  ..., 0.8863, 1.1847, 0.5687],
#          ...,
#          [1.4599, 1.5590, 1.5243,  ..., 1.5476, 1.4960, 1.4842],
#          [1.4237, 1.4285, 1.4660,  ..., 1.6618, 1.4848, 1.7099],
#          [1.4643, 1.4641, 1.5728,  ..., 1.7643, 1.6507, 1.4208]]])
# tensor([[[ 1.2004, -0.1667,  0.1072,  ...,  0.7510,  0.8138,  0.9101],
#          [ 0.4824,  0.0181,  0.4991,  ...,  0.4386,  0.6197,  0.8191],
#          [ 1.1593,  0.2280,  0.2682,  ...,  0.7510,  0.5646,  0.7388],
#          ...,
#          [ 1.7786,  1.6045,  1.4801,  ...,  1.4801,  1.2385,  1.6414],
#          [ 1.6839,  1.8384,  1.6409,  ...,  1.6018,  1.4343,  1.4614],
#          [ 1.5831,  1.7156,  1.5334,  ...,  1.4801,  1.5879,  1.5138]]])
# tensor([[[ 0.5724,  0.3317, -0.5155,  ...,  0.8903,  0.6839,  0.5255],
#          [ 0.9608,  0.3254,  0.2297,  ...,  0.8903, -0.2391,  0.4768],
#          [ 0.9967,  0.2133,  0.1805,  ...,  0.6244,  0.3606,  0.2483],
#          ...,
#          [ 1.4261,  1.6038,  1.4501,  ...,  1.5497,  1.5723,  1.4056],
#          [ 1.6659,  1.6332,  1.6111,  ...,  1.5497,  1.5927,  1.5050],
#          [ 1.5348,  1.7669,  1.5848,  ...,  1.5497,  1.7854,  1.7546]]])
# tensor([[[ 0.0487,  0.1941,  0.7491,  ...,  0.8903, -0.2955, -0.1453],
#          [ 0.7517,  0.7822,  0.7534,  ...,  0.8903, -0.5483, -0.3719],
#          [ 0.5079,  0.5124,  0.8641,  ...,  1.2733, -1.1348, -0.1315],
#          ...,
#          [ 1.4316,  1.5277,  1.4673,  ...,  1.5497, -1.4254, -1.3688],
#          [ 1.2520,  1.3012,  1.5440,  ...,  1.5497, -1.6503, -1.2315],
#          [ 1.3000,  1.6105,  1.5912,  ...,  1.5497, -1.3847, -1.3176]]])
# tensor([[[ 1.2823,  0.5439,  0.9265,  ...,  0.2614,  0.1030, -1.2124],
#          [ 1.3238,  0.6634,  1.0040,  ...,  0.6244, -0.6397, -1.3622],
#          [ 1.1878,  0.8759,  0.9631,  ..., -0.3145, -0.7234, -0.8379],
#          ...,
#          [ 1.8407,  1.3077,  1.4676,  ...,  1.2733, -1.5142, -1.5176],
#          [ 1.7716,  1.4731,  1.6649,  ...,  1.5497, -1.3985, -1.6270],
#          [ 1.6761,  1.5796,  1.5262,  ...,  1.5497, -1.4254, -1.7754]]])
# tensor([[[ 1.2156,  0.6677,  0.1736,  ...,  0.8903, -0.7345, -0.5524],
#          [ 1.0084,  0.6160,  0.4564,  ...,  1.1000, -0.3902, -0.7124],
#          [ 0.9361,  0.6797,  0.6782,  ...,  0.6244, -0.9695, -0.4291],
#          ...,
#          [ 1.8124,  1.5435,  1.5487,  ...,  1.4210, -1.5549, -1.6137],
#          [ 1.8612,  1.4279,  1.5131,  ...,  1.6636, -1.6652, -1.5218],
#          [ 1.7141,  1.3669,  1.5873,  ...,  1.6636, -1.5193, -1.4796]]])
# tensor([[[ 0.6658,  1.0676,  0.8296,  ..., -1.2765, -0.8400, -1.0169],
#          [ 0.6257,  1.1583,  1.0701,  ..., -1.2765, -0.5985, -1.2189],
#          [ 0.8452,  1.2591,  0.7960,  ..., -1.4795, -1.0728, -0.9769],
#          ...,
#          [ 1.3746,  1.4491,  1.4664,  ..., -0.6783, -1.2135, -1.4947],
#          [ 1.5755,  1.5394,  1.5231,  ..., -0.6783, -1.3654, -1.3968],
#          [ 1.2941,  1.7109,  1.4519,  ..., -1.2765, -1.3074, -1.5361]]])
# tensor([[[-0.0619,  0.7084,  0.6177,  ...,  0.8903,  0.4777,  1.8051],
#          [ 0.3889,  0.0514,  0.4342,  ...,  1.1000,  0.3101,  1.5936],
#          [ 0.6296,  0.6805,  0.5469,  ...,  0.6244,  0.8790,  1.7107],
#          ...,
#          [ 1.3371,  1.7059,  1.4928,  ...,  1.5497,  1.5783,  2.0442],
#          [ 1.1191,  1.7141,  1.5343,  ...,  1.6636,  1.5986,  1.9064],
#          [ 1.0938,  1.7212,  1.4815,  ...,  1.6636,  1.4700,  1.9644]]])
# tensor([[[ 1.2554,  0.4320,  0.9974,  ...,  1.1000,  0.3891, -2.4645],
#          [ 0.8350,  0.8094,  0.5332,  ...,  1.1000,  0.4223,  0.8316],
#          [ 1.2500,  0.2910,  1.0972,  ...,  0.6244,  0.0275,  0.1282],
#          ...,
#          [ 1.7043,  1.5799,  1.6642,  ...,  1.6636,  1.7058,  1.5797],
#          [ 1.5006,  1.3549,  1.5925,  ...,  1.7659,  1.6405,  1.5672],
#          [ 1.6581,  1.8046,  1.7910,  ...,  1.7659,  1.6308,  1.6796]]])
# tensor([[[-0.0701,  0.9330,  0.7384,  ...,  0.7510,  1.0529,  0.9476],
#          [ 0.2736,  1.1672,  0.5280,  ...,  1.1805,  0.8622,  1.0326],
#          [ 0.8773,  1.2198,  0.2675,  ...,  0.9887,  0.7275,  0.8935],
#          ...,
#          [ 1.3351,  1.9128,  1.6191,  ...,  1.6018,  1.6302,  1.7921],
#          [ 1.8771,  1.6133,  1.5488,  ...,  1.7102,  1.7143,  1.6862],
#          [ 1.5058,  1.6787,  1.6132,  ...,  1.7102,  1.7667,  1.7258]]])
# tensor([[[-1.1345,  1.6238, -1.6168,  ...,  1.0969,  1.2712,  1.4137],
#          [ 0.6563,  1.4017,  0.2144,  ...,  1.0969,  1.2137,  1.2142],
#          [ 0.6463,  1.3779, -0.2410,  ...,  0.2540,  1.3122,  1.3562],
#          ...,
#          [ 1.0656,  1.7635,  1.1505,  ...,  1.8572,  1.7840,  1.7478],
#          [ 1.0524,  1.8972,  1.2396,  ...,  1.6618,  1.6783,  1.8334],
#          [ 1.2349,  1.8283,  1.3962,  ...,  1.7643,  1.7756,  1.7436]]])
# tensor([[[ 0.8007,  1.1901,  0.0832,  ..., -0.2197,  0.6271,  1.3225],
#          [ 0.8671,  0.8714,  0.0161,  ...,  0.3157,  0.6002,  1.2329],
#          [ 0.7109,  0.7747,  0.1193,  ...,  0.3157,  0.6271,  1.2837],
#          ...,
#          [ 1.4342,  1.8591,  1.5495,  ...,  1.5649,  1.6008,  1.5750],
#          [ 1.5703,  1.8474,  1.5262,  ...,  1.5649,  1.4258,  1.4252],
#          [ 1.5462,  1.6870,  1.5525,  ...,  1.6773,  1.6207,  1.7662]]])
# tensor([[[ 1.1710, -0.0411,  0.8766,  ...,  0.8903, -0.0535,  0.7794],
#          [ 0.6550,  1.0701,  0.9130,  ...,  0.2614,  1.0607,  0.7263],
#          [ 0.3957,  0.9332,  0.5838,  ...,  0.2614,  0.9124,  0.5041],
#          ...,
#          [ 1.4665,  1.4631,  1.2914,  ...,  1.7659,  1.2628,  1.5540],
#          [ 1.6253,  1.4466,  1.5614,  ...,  1.7659,  1.5849,  1.6902],
#          [ 1.7083,  1.3418,  1.7266,  ...,  1.5497,  1.4067,  1.4807]]])
# tensor([[[ 0.4545,  0.8989,  0.1227,  ...,  0.6244, -0.7619, -0.6321],
#          [ 0.6620,  0.7620,  0.0505,  ...,  0.8903, -0.5310, -0.6375],
#          [ 0.5472,  0.7447,  0.6974,  ...,  0.6244, -0.7619, -0.7837],
#          ...,
#          [ 1.3532,  1.4238,  1.3842,  ...,  1.4210, -1.6657, -1.6031],
#          [ 1.6317,  1.6623,  1.3471,  ...,  1.4210, -1.6863, -1.5435],
#          [ 1.4652,  1.4765,  1.6118,  ...,  1.4210, -1.6121, -1.6700]]])
# tensor([[[ 0.1264,  0.1327, -0.1442,  ...,  1.2707, -0.3950, -0.5222],
#          [ 0.4660,  0.4636, -0.1208,  ...,  1.0969, -0.7894,  0.0040],
#          [-0.0184,  0.6840,  0.7201,  ...,  0.8863, -0.5964, -0.8863],
#          ...,
#          [ 1.4694,  1.2303,  1.5016,  ...,  1.6618, -1.6665, -1.3382],
#          [ 1.5698,  1.3256,  1.5438,  ...,  1.4187, -1.2605, -1.4676],
#          [ 1.5374,  1.4331,  1.4704,  ...,  1.7643, -1.6239, -1.5821]]])
# tensor([[[-0.0407,  0.8015,  0.6297,  ...,  0.3157,  0.3120,  0.6651],
#          [ 0.3364,  0.6496,  0.1640,  ...,  0.6626,  1.1177,  1.0060],
#          [ 0.6302,  1.1308,  0.6422,  ...,  0.3157,  0.6489,  0.8316],
#          ...,
#          [ 1.2699,  1.8623,  1.6591,  ...,  1.6773,  1.7483,  1.8133],
#          [ 1.5811,  1.8195,  1.4622,  ...,  1.5649,  1.4819,  1.7136],
#          [ 1.5613,  1.6138,  1.7141,  ...,  1.7782,  1.7739,  1.7366]]])
# tensor([[[ 0.7921, -1.6899,  0.8426,  ...,  0.4386, -1.3204, -0.7743],
#          [ 0.4913,  0.0593,  0.1983,  ...,  0.9887, -0.7365, -0.9419],
#          [ 0.6629, -0.3037,  0.5534,  ...,  0.4386, -0.9283, -1.1516],
#          ...,
#          [ 1.5743,  1.4118,  1.6861,  ...,  1.6018, -1.7931, -1.7182],
#          [ 1.6016,  1.7628,  1.5804,  ...,  1.7102, -1.6763, -1.7569],
#          [ 1.6055,  1.5005,  1.7124,  ...,  1.3415, -1.9383, -1.7205]]])
# tensor([[[-0.0165,  1.1932,  1.0942,  ..., -0.2197, -0.9759, -0.5768],
#          [ 0.2088,  0.8836,  0.6272,  ...,  0.6626, -0.6316, -0.6239],
#          [ 0.7831,  0.5123,  0.8100,  ...,  0.6626, -0.2841,  0.6939],
#          ...,
#          [ 1.2764,  1.7350,  1.6925,  ...,  1.4384, -1.4217, -1.6084],
#          [ 1.5976,  1.7412,  1.6077,  ...,  1.4384, -1.5585, -1.6487],
#          [ 1.6793,  1.5416,  1.6923,  ...,  1.2935, -1.6039, -1.7591]]])
# tensor([[[ 0.3968,  0.1034, -0.3546,  ...,  0.7510,  0.9172,  0.4934],
#          [-0.3523, -0.1654, -0.4770,  ...,  0.4386,  1.1471,  0.7333],
#          [ 0.7594,  0.8911,  0.1649,  ...,  0.9887,  1.0299,  0.4313],
#          ...,
#          [ 1.5833,  1.7297,  1.6755,  ...,  1.7102,  1.7381,  1.6801],
#          [ 1.3199,  1.7500,  1.5981,  ...,  1.6018,  1.7115,  1.5298],
#          [ 1.6066,  1.6315,  1.6303,  ...,  1.6018,  1.8844,  1.7868]]])
# tensor([[[-0.3510,  0.2761,  0.3953,  ...,  0.6244, -0.6651,  0.4889],
#          [ 0.7687,  0.5365,  0.2478,  ...,  0.6244, -0.6931, -0.5300],
#          [ 0.1990,  0.8476,  0.2877,  ...,  0.8903, -0.3311,  1.2530],
#          ...,
#          [ 1.3892,  1.2477,  1.1544,  ...,  1.4210, -1.3692, -0.9896],
#          [ 1.4034,  1.2490,  1.2899,  ...,  1.5497, -1.5368, -1.3058],
#          [ 1.2067,  1.3631,  1.4163,  ...,  1.4210, -1.5249, -1.4596]]])
# tensor([[[ 1.0427,  0.9116,  0.7037,  ...,  1.2707, -1.1801, -0.8532],
#          [ 1.3128,  1.1647,  1.0527,  ...,  0.2540, -1.0145, -0.4750],
#          [ 1.0360,  1.2103,  0.8998,  ...,  1.0969, -0.8865, -0.7490],
#          ...,
#          [ 1.4956,  1.4682,  1.5368,  ...,  1.6618, -1.5217, -1.4845],
#          [ 1.6968,  1.5722,  1.4101,  ...,  1.7643, -1.4335, -1.4745],
#          [ 1.6241,  1.6157,  1.4932,  ...,  1.8572, -1.7758, -1.6020]]])
# tensor([[[ 0.9121,  0.4058,  0.4323,  ...,  0.6244, -1.0000, -0.1671],
#          [ 0.7810,  0.8358,  0.2306,  ...,  0.2614, -0.6935, -0.2461],
#          [ 1.1741,  0.4442,  0.6034,  ...,  0.6244, -0.2052, -0.3931],
#          ...,
#          [ 1.6310,  1.5187,  1.4822,  ...,  1.2733, -1.6168, -1.6330],
#          [ 1.6159,  1.4183,  1.6227,  ...,  1.7659, -1.5834, -1.5561],
#          [ 1.7239,  1.5350,  1.7251,  ...,  1.6636, -1.6702, -1.6537]]])
# tensor([[[ 1.4067,  1.2015, -0.0975,  ...,  0.8863, -0.8421, -0.0308],
#          [ 1.1152,  1.1075,  0.6854,  ...,  1.0969, -0.9330, -0.7639],
#          [ 1.2661,  0.7421,  0.7434,  ...,  0.8863, -0.6013, -0.7543],
#          ...,
#          [ 1.9633,  1.4351,  1.3298,  ...,  1.2707, -1.5347, -1.1980],
#          [ 1.5341,  1.2751,  1.4646,  ...,  1.2707, -1.6256, -1.3401],
#          [ 1.7249,  1.5333,  1.3387,  ...,  1.4187, -1.7766, -1.3740]]])
# tensor([[[ 1.2265,  0.4877, -0.3605,  ...,  0.6244, -0.3125, -1.2416],
#          [ 1.3072,  0.4822, -0.2122,  ..., -0.3145, -0.1363, -0.1042],
#          [ 1.0557,  0.6049,  0.2320,  ...,  0.6244, -0.1363, -1.0287],
#          ...,
#          [ 1.5207,  1.6609,  1.3328,  ...,  1.6636, -1.4176, -1.6732],
#          [ 1.6788,  1.5039,  1.2718,  ...,  1.5497, -1.5665, -1.8607],
#          [ 1.5536,  1.6764,  1.2945,  ...,  1.6636, -1.3339, -1.6453]]])
# tensor([[[ 0.6109,  0.3122, -0.2878,  ...,  1.1000,  0.3293,  0.5434],
#          [ 0.7734,  0.5981, -0.3570,  ...,  0.8903,  0.3644,  0.7195],
#          [ 0.2528,  0.8533, -0.0960,  ...,  0.2614,  0.8899,  0.6660],
#          ...,
#          [ 1.3965,  1.5409,  1.3723,  ...,  1.7659,  1.6622,  1.5515],
#          [ 1.4290,  1.5909,  1.2426,  ...,  1.6636,  1.6716,  1.6181],
#          [ 1.6390,  1.5311,  1.6631,  ...,  1.7659,  1.7438,  1.6923]]])
# tensor([[[ 0.9954, -0.1461,  0.2548,  ...,  0.8903, -0.0775,  0.5196],
#          [ 0.9667,  0.2233,  0.0436,  ...,  0.8903,  0.6526,  0.7847],
#          [-0.3592, -0.2220, -0.3126,  ...,  0.2614,  0.5139,  0.5106],
#          ...,
#          [ 1.6209,  1.7844,  1.5363,  ...,  1.6636,  1.5490,  1.4066],
#          [ 1.7351,  1.6382,  1.5093,  ...,  1.5497,  1.4607,  1.5075],
#          [ 1.5902,  1.5481,  1.4670,  ...,  1.5497,  1.5905,  1.4957]]])
# tensor([[[ 0.6523,  1.0403, -0.1601,  ...,  1.2707, -0.4163, -0.8248],
#          [ 0.5136,  0.1849, -0.2585,  ...,  1.0969, -0.9634, -0.6597],
#          [ 0.1442,  1.0387,  0.3592,  ...,  0.8863, -0.4866, -0.8618],
#          ...,
#          [ 1.6503,  1.7824,  1.5554,  ...,  1.5476, -1.5035, -1.6125],
#          [ 1.4828,  1.7221,  1.5829,  ...,  1.5476, -1.5157, -1.7568],
#          [ 1.5936,  1.6936,  1.7300,  ...,  1.7643, -1.7712, -1.5004]]])
# tensor([[[-0.2738,  1.2469,  0.3925,  ...,  0.8903, -0.7345, -1.2593],
#          [-0.0699,  0.8216,  0.6130,  ..., -0.3145, -1.0304, -0.8113],
#          [ 0.4469,  1.0295, -0.1174,  ...,  0.2614, -0.1363,  0.0227],
#          ...,
#          [ 1.4491,  1.7611,  1.5974,  ...,  1.5497, -1.6441, -1.4657],
#          [ 1.7223,  1.7140,  1.3903,  ...,  1.6636, -1.6115, -1.7769],
#          [ 1.3794,  1.7212,  1.5718,  ...,  1.7659, -1.8197, -1.6713]]])
# tensor([[[ 1.2380,  0.2377,  0.7403,  ...,  0.3157,  0.4927,  0.4576],
#          [ 0.3786,  0.7205,  0.8285,  ...,  0.6626,  0.6856,  0.6078],
#          [ 0.8901,  0.8060,  0.6943,  ...,  0.6626,  0.7345, -0.1055],
#          ...,
#          [ 1.7244,  1.8272,  1.6221,  ...,  1.5649,  1.4641,  1.4419],
#          [ 1.6353,  1.6659,  1.8050,  ...,  1.5649,  1.5200,  1.4406],
#          [ 1.5539,  1.4412,  1.7125,  ...,  1.5649,  1.4525,  1.5108]]])
# tensor([[[ 0.9496,  1.1759,  0.2860,  ...,  0.4386,  1.2397,  1.1196],
#          [ 1.0482,  0.5800,  0.4469,  ...,  0.7510,  0.6218,  1.0135],
#          [ 1.0681,  0.7265,  0.5231,  ..., -0.0181,  1.0145,  1.1402],
#          ...,
#          [ 1.4948,  1.5062,  1.5613,  ...,  1.3415,  1.6383,  1.5872],
#          [ 1.6891,  1.5364,  1.4506,  ...,  1.6018,  1.6574,  1.4961],
#          [ 1.2751,  1.7226,  1.5955,  ...,  1.4801,  1.7306,  1.6426]]])
# tensor([[[ 0.9218, -0.4290,  0.0520,  ...,  1.1000, -1.7607, -1.7899],
#          [ 0.7568,  0.6823,  0.1701,  ...,  0.8903,  0.1109,  0.1185],
#          [ 0.4058,  0.5866,  0.3396,  ...,  0.8903,  0.1109,  0.1875],
#          ...,
#          [ 1.6469,  1.4393,  1.3886,  ...,  1.6636,  1.4474,  1.4590],
#          [ 1.5462,  1.2426,  1.4704,  ...,  1.7659,  1.3871,  1.5286],
#          [ 1.3585,  1.6370,  1.3454,  ...,  1.7659,  1.5043,  1.4470]]])
# tensor([[[ 1.1032,  1.0067,  1.4103,  ...,  1.5152,  0.3405, -1.0344],
#          [ 1.1345,  1.0960,  1.1632,  ...,  1.3818, -0.3950, -0.9882],
#          [ 1.0905,  1.0686,  0.9430,  ...,  1.2277, -0.9511, -0.8015],
#          ...,
#          [ 1.9528,  1.4272,  1.7323,  ...,  1.5152, -1.3358, -1.3895],
#          [ 1.6474,  1.6169,  1.7372,  ...,  1.7383, -1.0524, -1.4072],
#          [ 1.7081,  1.6172,  1.8419,  ...,  1.6329, -1.6019, -1.6537]]])
# tensor([[[0.9883, 1.3085, 0.6919,  ..., 0.4386, 1.1592, 0.4681],
#          [0.8594, 0.8062, 0.5781,  ..., 0.7510, 1.2487, 0.8531],
#          [0.8834, 0.9364, 0.3060,  ..., 0.9887, 1.1899, 0.0574],
#          ...,
#          [1.3338, 2.0177, 1.4727,  ..., 1.6018, 1.6051, 1.5256],
#          [1.4919, 1.8822, 1.3875,  ..., 1.4801, 1.6634, 1.3620],
#          [1.6396, 1.7515, 1.4876,  ..., 1.6018, 1.6913, 1.6011]]])
# tensor([[[ 0.0549,  0.4197,  0.7965,  ..., -0.2197,  0.4778,  0.7594],
#          [ 0.7814,  0.5353,  0.6869,  ..., -0.2197,  0.7467,  0.6440],
#          [ 0.8491,  1.1506,  0.3717,  ..., -1.4516,  0.8369,  0.6613],
#          ...,
#          [ 1.4377,  1.8302,  1.5188,  ...,  1.5649,  1.6945,  1.6893],
#          [ 1.4286,  1.6618,  1.5618,  ...,  1.4384,  1.6185,  1.6387],
#          [ 1.6236,  1.8715,  1.5258,  ...,  1.5649,  1.7215,  1.9668]]])
# tensor([[[ 0.4856,  1.2438,  0.4791,  ...,  0.4386,  0.5663, -0.7043],
#          [ 0.8387,  1.1903,  0.2027,  ..., -0.0181,  0.9195,  0.2398],
#          [ 0.2476,  0.6320,  0.1416,  ...,  0.7510,  0.7228,  0.6432],
#          ...,
#          [ 1.5068,  1.7743,  1.5448,  ...,  1.4801,  1.4700,  1.3767],
#          [ 1.5277,  1.6596,  1.3532,  ...,  1.4801,  1.5364,  1.3366],
#          [ 1.5236,  1.6509,  1.4248,  ...,  1.4801,  1.6945,  1.5886]]])
# tensor([[[ 0.6230,  1.4351,  1.6490,  ...,  1.3818, -1.2376, -1.4249],
#          [ 0.6923,  1.0502,  1.5153,  ...,  1.2277, -1.2691, -1.2341],
#          [ 0.5703,  1.2506,  1.5119,  ...,  1.3818, -0.9837, -1.3550],
#          ...,
#          [ 1.3587,  1.4756,  1.8338,  ...,  1.5152, -1.6826, -1.8473],
#          [ 1.5090,  1.5697,  1.9026,  ...,  1.6329, -1.7327, -1.8124],
#          [ 1.6359,  1.5623,  1.8413,  ...,  1.6329, -1.4657, -1.8088]]])
# tensor([[[ 0.9687,  1.2335,  0.0715,  ...,  1.1000,  0.6846,  0.3210],
#          [ 0.6155,  0.5100, -1.1492,  ...,  0.6244,  0.2518,  0.6125],
#          [ 1.2348,  0.5179,  0.1261,  ...,  0.6244, -0.4471,  0.6223],
#          ...,
#          [ 1.7885,  1.5211,  1.4875,  ...,  1.7659,  1.3149,  1.5206],
#          [ 1.6294,  1.8039,  1.4424,  ...,  1.7659,  1.6520,  1.6164],
#          [ 1.7724,  1.8813,  1.6998,  ...,  1.7659,  1.4976,  1.6729]]])
# tensor([[[ 0.4417,  0.2385, -0.0626,  ...,  0.4386,  1.2740,  0.9510],
#          [ 0.7734,  0.3995, -0.4186,  ..., -0.8830,  1.1242,  0.8514],
#          [ 0.4168,  0.0438,  0.3566,  ..., -0.0181,  0.6846,  0.6598],
#          ...,
#          [ 1.0757,  1.4281,  1.3361,  ...,  1.4801,  1.7431,  1.6044],
#          [ 1.4152,  1.5894,  1.5414,  ...,  1.3415,  1.6520,  1.5719],
#          [ 1.4650,  1.4150,  1.5086,  ...,  1.4801,  1.5622,  1.7947]]])
# tensor([[[-1.0799,  0.4195,  0.7033,  ...,  0.4386, -0.7961,  0.1797],
#          [ 0.7042,  0.5781,  0.6952,  ...,  0.4386, -0.3284, -0.0346],
#          [-0.3525,  0.2263,  0.3929,  ...,  0.7510, -0.7450, -0.6783],
#          ...,
#          [ 1.6805,  1.7109,  1.6684,  ...,  1.6018, -1.6899, -1.5259],
#          [ 1.4171,  1.4561,  1.6798,  ...,  1.4801, -1.3682, -1.5202],
#          [ 1.9585,  1.6772,  1.6554,  ...,  1.6018, -1.7492, -1.2977]]])
# tensor([[[ 0.8014,  1.0957, -0.4565,  ...,  1.0969, -1.4261, -0.8324],
#          [ 0.6927,  1.5464, -0.0219,  ...,  0.8863, -1.3992, -0.7095],
#          [ 0.6438,  1.1672,  0.2112,  ...,  1.4187, -1.0997, -0.8946],
#          ...,
#          [ 1.3736,  1.7134,  1.4266,  ...,  1.5476, -1.7322, -1.2879],
#          [ 1.4162,  1.9232,  1.4286,  ...,  1.4187, -1.8689, -1.6369],
#          [ 1.4835,  1.6455,  1.4345,  ...,  1.7643, -1.8074, -1.6329]]])
# tensor([[[ 1.2504,  0.9562, -0.5534,  ...,  0.8903,  0.5654,  1.3076],
#          [ 1.2170,  0.9523,  0.3088,  ...,  0.6244,  0.5654,  1.0025],
#          [ 0.7847,  1.0385,  0.4150,  ...,  0.6244,  0.2331,  0.8314],
#          ...,
#          [ 1.3192,  1.6460,  1.3908,  ...,  1.4210,  1.4107,  1.8145],
#          [ 1.7046,  1.5100,  1.4583,  ...,  1.8587,  1.4922,  1.8036],
#          [ 1.5669,  1.6949,  1.4808,  ...,  1.6636,  1.3861,  1.7095]]])
# tensor([[[ 0.3382,  1.0683, -1.3180,  ..., -0.0181, -0.7450, -0.7653],
#          [ 0.6416,  0.8740, -0.6453,  ...,  0.4386, -0.9135, -0.3151],
#          [ 0.8820,  0.8212, -0.8104,  ...,  0.4386, -0.3674, -0.6519],
#          ...,
#          [ 1.4012,  1.7288,  1.4672,  ...,  0.9887, -1.3822, -1.6974],
#          [ 1.6088,  1.5871,  1.5347,  ...,  1.4801, -1.6159, -1.2944],
#          [ 1.6646,  1.6786,  1.6353,  ...,  1.4801, -1.7298, -1.4449]]])
# tensor([[[ 0.4103,  0.6609,  0.8830,  ...,  0.6244, -1.0718, -0.2767],
#          [ 0.4953,  0.5638,  0.5111,  ...,  0.8903, -1.0134, -0.1015],
#          [ 0.5950,  0.8689,  0.8847,  ...,  0.8903,  0.1302, -0.9033],
#          ...,
#          [ 1.3651,  1.7897,  1.4218,  ...,  1.4210, -1.6021, -1.6617],
#          [ 1.4975,  1.5807,  1.4884,  ...,  1.7659, -1.4328, -1.5067],
#          [ 1.0322,  1.3960,  1.6958,  ...,  1.6636, -1.6667, -1.4473]]])
# tensor([[[ 0.6151, -0.3211,  0.2880,  ..., -1.4516, -0.5337, -0.4828],
#          [ 0.2587,  0.6982,  0.5840,  ...,  0.3157, -0.2339, -0.4081],
#          [ 0.7411,  0.6901, -0.2722,  ...,  0.3157, -0.3950, -0.6143],
#          ...,
#          [ 1.6910,  1.2048,  1.7472,  ...,  1.2935, -1.5447, -1.3707],
#          [ 1.7325,  1.4900,  1.5369,  ...,  1.4384, -1.4326, -1.7066],
#          [ 1.7819,  1.3899,  1.6297,  ...,  1.4384, -1.5564, -1.4872]]])
# tensor([[[ 0.7930,  0.6712, -0.8067,  ...,  1.5152,  0.5245, -1.3915],
#          [ 0.9599, -0.5872,  0.1971,  ...,  1.2277, -0.8812, -0.7266],
#          [ 0.8016,  0.6750,  0.5098,  ...,  1.3818, -0.0850, -1.2809],
#          ...,
#          [ 1.3881,  1.6501,  1.4332,  ...,  1.8335, -1.4819, -1.7787],
#          [ 1.7910,  1.6238,  1.5458,  ...,  1.7383, -1.4692, -1.7647],
#          [ 1.5008,  1.4132,  1.5705,  ...,  1.6329, -1.4036, -1.5663]]])
# tensor([[[ 0.9916,  0.6011,  0.7231,  ...,  1.3818, -0.7790, -0.7961],
#          [ 1.3610,  0.8667,  0.7086,  ...,  1.3818, -0.4166, -0.9026],
#          [ 0.5536,  0.6335,  0.9186,  ...,  1.3818, -0.3010, -0.5512],
#          ...,
#          [ 1.6450,  1.5013,  1.4809,  ...,  1.8335, -1.3586, -1.6496],
#          [ 1.4041,  1.2534,  1.5564,  ...,  1.8335, -1.5632, -1.4643],
#          [ 1.5024,  1.5582,  1.5018,  ...,  1.6329, -1.4003, -1.2405]]])
# tensor([[[ 1.1156,  0.6711,  0.7901,  ...,  0.3157,  1.0913,  0.7694],
#          [ 1.2054,  0.1168,  0.9107,  ...,  0.6626,  0.7335,  0.6912],
#          [ 0.7213,  0.6628, -0.0351,  ...,  0.6626,  0.6592,  0.2423],
#          ...,
#          [ 1.5668,  1.6735,  1.6080,  ...,  1.4384,  1.7255,  1.7073],
#          [ 1.5425,  1.6526,  1.5950,  ...,  1.5649,  1.6802,  1.4850],
#          [ 1.7814,  1.7725,  1.5981,  ...,  1.6773,  1.7430,  1.7806]]])
# tensor([[[ 1.3610,  1.4794,  0.6987,  ...,  1.3818, -0.3774, -0.6045],
#          [ 1.3947,  0.8321,  0.7737,  ...,  1.2277, -0.6124, -0.1919],
#          [ 1.3210,  1.4364,  0.6155,  ...,  1.2277, -0.7519, -0.6928],
#          ...,
#          [ 1.9150,  1.6277,  1.5719,  ...,  1.3818, -1.3995, -1.3206],
#          [ 1.7533,  1.7558,  1.3652,  ...,  1.6329, -1.5854, -1.2039],
#          [ 1.9290,  1.6906,  1.4870,  ...,  1.7383, -1.5151, -1.4206]]])
# tensor([[[ 0.9328,  1.2288,  0.4241,  ..., -2.0201,  0.7550,  0.0591],
#          [ 0.9253,  0.9592,  0.4407,  ...,  0.6088,  0.8007,  0.6885],
#          [ 0.5641,  0.7668,  0.2305,  ...,  0.6088,  0.4576,  0.8393],
#          ...,
#          [ 1.4498,  1.6237,  1.5336,  ...,  1.4140,  1.6885,  1.2215],
#          [ 1.4937,  1.6846,  1.3085,  ...,  1.4140,  1.4153,  1.4842],
#          [ 1.4980,  1.7745,  1.4094,  ...,  1.5435,  1.7247,  1.2067]]])
# tensor([[[ 1.6569,  1.1739,  0.3829,  ..., -0.8830, -1.2001,  1.9372],
#          [ 1.5328,  0.5870,  0.4925,  ...,  0.4386, -1.0950, -0.5476],
#          [ 1.0748,  0.9708,  0.7202,  ..., -0.0181, -1.0574, -0.3322],
#          ...,
#          [ 1.8427,  1.5913,  1.4330,  ...,  0.9887, -1.7491, -1.2712],
#          [ 1.7930,  1.7091,  1.5786,  ...,  1.1805, -1.5359, -1.5410],
#          [ 1.8784,  1.3833,  1.4308,  ...,  0.9887, -1.6482, -1.3142]]])
# tensor([[[ 0.9116,  0.2552, -0.2248,  ..., -0.0181,  0.3402,  1.4270],
#          [ 0.7265,  0.3223,  0.3852,  ..., -0.0181,  0.7189,  1.1385],
#          [ 1.2855, -0.1249,  0.4977,  ...,  0.4386,  0.1014,  1.0131],
#          ...,
#          [ 1.3955,  1.4406,  1.4472,  ...,  1.3415,  1.5766,  1.9135],
#          [ 1.4002,  1.3722,  1.3526,  ...,  0.9887,  1.5970,  1.8495],
#          [ 1.6195,  1.7639,  1.3802,  ...,  1.4801,  1.2932,  1.8906]]])
# tensor([[[-0.0997, -0.4815,  0.1286,  ...,  1.1000,  1.0064,  0.4331],
#          [-0.1880, -0.0182,  0.6470,  ...,  0.6244,  0.7602,  0.3115],
#          [-1.6210,  0.6937,  0.5964,  ...,  0.8903,  1.0595,  0.4233],
#          ...,
#          [ 1.5698,  1.3851,  1.4953,  ...,  1.6636,  1.5636,  1.5174],
#          [ 1.4011,  1.3817,  1.6345,  ...,  1.7659,  1.7528,  1.5123],
#          [ 1.5292,  1.4243,  1.5090,  ...,  1.6636,  1.7442,  1.5462]]])
# tensor([[[ 1.2952,  1.1899, -0.0851,  ..., -0.0181, -0.4065, -0.5230],
#          [ 1.1056,  1.3694,  0.3168,  ...,  0.9887, -0.8691, -1.0265],
#          [ 1.0928,  1.2263,  0.3116,  ...,  0.4386, -0.8457, -0.9859],
#          ...,
#          [ 1.5803,  1.7185,  1.3236,  ...,  1.4801, -1.5365, -1.2588],
#          [ 1.7987,  1.5484,  1.5424,  ...,  1.3415, -1.6164, -1.6101],
#          [ 1.8019,  1.6247,  1.2392,  ...,  1.7102, -1.5483, -1.4870]]])
# tensor([[[-0.1132,  0.5109,  0.0417,  ...,  0.7510,  0.2055,  0.6274],
#          [ 0.4461,  0.4931,  0.0057,  ...,  0.4386,  0.5741,  0.7434],
#          [ 0.2281,  0.3681, -0.7260,  ...,  0.4386,  0.6548,  0.7056],
#          ...,
#          [ 1.5265,  1.4673,  1.4159,  ...,  1.7102,  1.4383,  1.6577],
#          [ 1.4884,  1.6091,  1.5088,  ...,  1.6018,  1.7061,  1.7381],
#          [ 1.5592,  1.7617,  1.3364,  ...,  1.4801,  1.6786,  1.7417]]])
# tensor([[[ 0.8762,  0.9522,  1.1978,  ...,  1.2707,  0.4744, -0.5730],
#          [ 0.4572,  0.3504,  0.8759,  ...,  1.2707, -0.5775, -0.5522],
#          [ 0.8841,  0.6654,  0.5976,  ...,  1.0969, -0.0620, -0.1201],
#          ...,
#          [ 1.5589,  1.4126,  1.6826,  ...,  1.6618, -1.1511, -1.5523],
#          [ 1.6656,  1.5035,  1.6675,  ...,  1.7643, -1.3121, -1.2079],
#          [ 1.3786,  1.3865,  1.7975,  ...,  1.7643, -1.4111, -1.4495]]])
# tensor([[[ 1.3682, -0.8626,  0.1300,  ..., -0.0181,  0.1248, -0.0667],
#          [ 1.1815,  0.9627,  0.0417,  ..., -0.0181, -0.5369, -0.3526],
#          [ 1.2161,  0.2408, -0.5098,  ...,  0.4386, -0.8873,  0.1127],
#          ...,
#          [ 1.8434,  1.0522,  1.4862,  ...,  1.1805, -1.5691, -1.3434],
#          [ 1.8343,  1.4507,  1.3412,  ...,  1.4801, -1.4976, -1.4209],
#          [ 1.9791,  1.4462,  1.5794,  ...,  1.6018, -1.3659, -1.4725]]])
# tensor([[[-0.1250,  0.7654,  0.7863,  ...,  0.8903,  1.3391, -0.4160],
#          [ 0.8805,  1.0407,  0.4200,  ...,  0.6244, -0.4961, -0.3478],
#          [-0.4261,  0.7085,  0.4550,  ...,  0.6244, -0.8107, -0.7500],
#          ...,
#          [ 1.4597,  1.4230,  1.6244,  ...,  1.5497, -1.4822, -1.7582],
#          [ 1.5325,  1.7249,  1.7042,  ...,  1.5497, -1.5778, -1.6091],
#          [ 1.6603,  1.7487,  1.8189,  ...,  1.4210, -1.7060, -1.6775]]])
# tensor([[[ 0.3029, -0.4318,  0.6008,  ...,  0.6244,  0.4481, -1.0866],
#          [ 0.1670, -1.0012,  0.2962,  ..., -0.3145, -0.7026, -0.9081],
#          [ 0.5181,  0.8017,  0.2801,  ...,  0.6244,  0.2176,  0.0130],
#          ...,
#          [ 1.5795,  1.5917,  1.5266,  ...,  1.5497, -1.7339, -1.4021],
#          [ 1.2568,  1.3089,  1.4932,  ...,  1.2733, -1.5643, -1.7337],
#          [ 1.3252,  1.5902,  1.6216,  ...,  1.4210, -1.5527, -1.6021]]])
# tensor([[[-0.0080,  1.5002,  0.0429,  ...,  0.8863, -0.3050, -1.0969],
#          [ 0.4483,  1.1029,  0.5630,  ...,  0.6194, -0.3050, -0.4508],
#          [-0.7033,  1.4963,  0.5382,  ...,  0.6194, -0.6171, -1.0222],
#          ...,
#          [ 1.2013,  1.5686,  1.5297,  ...,  1.5476, -1.3017, -1.5914],
#          [ 1.2627,  1.7340,  1.4237,  ...,  1.4187, -1.3741, -1.6259],
#          [ 1.2841,  1.8284,  1.3418,  ...,  1.4187, -1.6421, -1.6835]]])
# tensor([[[ 0.9828,  0.4227,  0.0314,  ...,  0.8903, -0.8090, -0.4946],
#          [ 0.6047,  0.7743, -0.0919,  ...,  1.1000, -0.7841, -0.4097],
#          [ 0.7944,  0.4986,  0.3534,  ...,  1.1000, -0.8801, -0.4716],
#          ...,
#          [ 1.3500,  1.5049,  1.5413,  ...,  1.5497, -1.4429, -1.4242],
#          [ 1.4799,  1.5896,  1.6057,  ...,  1.5497, -1.6850, -1.4122],
#          [ 1.5949,  1.5890,  1.5676,  ...,  1.7659, -1.6432, -1.4389]]])
# tensor([[[ 1.7196,  1.7326,  0.4854,  ...,  0.2614,  0.0888, -1.3135],
#          [ 1.3159,  1.2652,  0.2120,  ..., -0.3145,  0.5383, -0.9762],
#          [ 1.5067,  1.4386,  0.5728,  ...,  0.2614, -0.8546, -1.0178],
#          ...,
#          [ 1.9037,  1.9295,  1.5620,  ...,  1.4210, -1.4800, -1.4881],
#          [ 1.8600,  1.7901,  1.3160,  ...,  1.4210, -1.3313, -1.7467],
#          [ 2.0542,  1.9307,  1.3824,  ...,  1.2733, -1.4151, -1.6990]]])
# tensor([[[-0.5246, -0.4196,  0.3286,  ..., -0.0181,  0.7138,  0.7316],
#          [ 0.2319,  0.5819, -0.3062,  ...,  0.4386,  0.6070, -0.4303],
#          [ 0.3598,  0.4345,  0.0636,  ...,  0.7510, -0.7108, -0.6540],
#          ...,
#          [ 1.4318,  1.4749,  1.4384,  ...,  1.3415, -1.5206, -1.5221],
#          [ 1.4633,  1.4840,  1.5049,  ...,  1.3415, -1.5678, -1.5259],
#          [ 1.6632,  1.3985,  1.5358,  ...,  1.3415, -1.5445, -1.4317]]])
# tensor([[[ 0.8085,  0.8090,  0.8299,  ...,  0.3157,  0.5377, -0.1621],
#          [ 0.1603,  0.7805,  0.5024,  ..., -0.2197,  0.5663,  0.2042],
#          [ 0.4174,  0.3365,  0.2855,  ...,  0.9196,  0.4141,  0.6065],
#          ...,
#          [ 1.5211,  1.4991,  1.4274,  ...,  1.5649,  1.7304,  1.4514],
#          [ 1.6791,  1.2771,  1.6310,  ...,  1.7782,  1.6667,  1.6463],
#          [ 1.6166,  1.5956,  1.6214,  ...,  1.5649,  1.6086,  1.5934]]])
# tensor([[[ 5.4917e-01, -8.6236e-04, -1.5484e-01,  ...,  4.3863e-01,
#            1.1704e+00,  7.1127e-01],
#          [-5.3672e-01,  6.2665e-01,  3.6307e-01,  ...,  9.8866e-01,
#            1.1230e+00,  6.3213e-01],
#          [ 9.5985e-01,  5.5931e-01, -2.8206e-01,  ...,  7.5099e-01,
#            6.0432e-01,  6.2992e-01],
#          ...,
#          [ 1.5506e+00,  1.5333e+00,  1.4205e+00,  ...,  1.4801e+00,
#            1.7337e+00,  1.2840e+00],
#          [ 1.2556e+00,  1.3486e+00,  1.4920e+00,  ...,  1.6018e+00,
#            1.5403e+00,  1.2215e+00],
#          [ 1.3928e+00,  1.2396e+00,  1.5403e+00,  ...,  1.3415e+00,
#            1.7424e+00,  1.6266e+00]]])
# tensor([[[ 1.5003,  0.8572,  0.6380,  ...,  1.1000, -0.5239,  0.5503],
#          [ 1.2161,  0.5504,  0.3434,  ...,  0.2614,  0.2537,  0.9703],
#          [ 1.2273,  0.8622, -0.2772,  ...,  0.6244,  0.4929,  0.5455],
#          ...,
#          [ 1.9791,  1.6207,  1.5002,  ...,  1.4210,  1.6990,  1.7193],
#          [ 1.6686,  1.5768,  1.5404,  ...,  1.6636,  1.5731,  1.7282],
#          [ 1.7874,  1.5919,  1.6401,  ...,  1.7659,  1.7259,  1.6590]]])
# tensor([[[ 7.2556e-04,  1.0682e+00,  9.4600e-01,  ..., -1.8108e-02,
#           -5.7113e-01, -6.9647e-01],
#          [ 7.0960e-01,  2.2037e-01,  4.3702e-01,  ...,  7.5099e-01,
#           -9.9651e-01, -6.7863e-01],
#          [ 7.3742e-01,  1.3237e+00,  8.9046e-01,  ...,  7.5099e-01,
#           -6.3164e-01, -3.2028e-01],
#          ...,
#          [ 1.0950e+00,  1.3469e+00,  1.5378e+00,  ...,  1.4801e+00,
#           -8.8903e-01, -1.6572e+00],
#          [ 1.4105e+00,  1.7280e+00,  1.4959e+00,  ...,  1.6018e+00,
#           -1.5468e+00, -1.5057e+00],
#          [ 1.2918e+00,  1.5290e+00,  1.5350e+00,  ...,  1.3415e+00,
#           -1.5109e+00, -1.7321e+00]]])
# tensor([[[-2.6726,  0.3342,  0.0625,  ...,  0.8903,  0.2550,  0.4651],
#          [ 0.6542,  0.2989,  0.2535,  ...,  0.6244,  0.0875,  0.6328],
#          [ 0.2267,  0.4341,  0.1357,  ...,  0.2614,  0.5238,  0.3741],
#          ...,
#          [ 1.5629,  1.5402,  1.5547,  ...,  1.6636,  1.6432,  1.7207],
#          [ 1.3036,  1.7343,  1.5875,  ...,  1.6636,  1.6902,  1.5584],
#          [ 1.4750,  1.6707,  1.6376,  ...,  1.6636,  1.5837,  1.6594]]])
# tensor([[[ 1.9018, -0.2022,  1.1928,  ...,  1.3818, -1.4294, -0.1303],
#          [ 1.8461,  0.5759,  1.0491,  ...,  1.0455, -1.1577, -0.5950],
#          [ 1.6860,  0.6234,  0.8504,  ...,  1.3818, -1.3028, -0.4771],
#          ...,
#          [ 1.9465,  1.2738,  1.6523,  ...,  1.6329, -1.7729, -1.5251],
#          [ 1.9840,  1.1572,  1.6139,  ...,  1.6329, -1.7050, -1.5102],
#          [ 2.0074,  1.5666,  1.6448,  ...,  1.5152, -1.6640, -1.4313]]])
# tensor([[[ 0.3601,  1.2391,  0.2938,  ..., -0.0181,  0.9029,  1.2505],
#          [ 0.4615,  0.8310,  0.4689,  ..., -0.0181,  0.7966,  1.1911],
#          [ 0.8385,  1.0988, -0.1538,  ...,  0.4386,  0.7966,  0.7744],
#          ...,
#          [ 1.1845,  1.7390,  1.5301,  ...,  1.3415,  1.5166,  1.5792],
#          [ 1.1845,  1.5405,  1.4317,  ...,  1.3415,  1.4370,  1.7746],
#          [ 1.3756,  1.6116,  1.4499,  ...,  1.6018,  1.3506,  1.7067]]])
# tensor([[[ 1.0662,  0.0100,  0.4476,  ...,  1.0969,  0.6571, -0.9009],
#          [ 1.0121,  0.7889, -0.3582,  ...,  1.2707, -0.3377, -0.1279],
#          [ 1.0121,  0.5419,  0.4157,  ...,  0.8863, -0.7247, -0.9772],
#          ...,
#          [ 1.6521,  1.3939,  1.3834,  ...,  1.4187, -1.5388, -1.4722],
#          [ 1.3458,  1.2935,  1.3867,  ...,  1.5476, -1.4522, -1.6849],
#          [ 1.6147,  1.4910,  1.6408,  ...,  1.5476, -1.5269, -1.6598]]])
# tensor([[[ 1.3748,  0.8081, -0.0274,  ...,  0.4386,  0.3946, -0.4336],
#          [ 1.0458,  1.0728, -0.7154,  ...,  0.4386, -0.4778, -0.2170],
#          [ 1.2405,  0.9918, -0.1268,  ...,  0.4386,  1.2466,  0.7582],
#          ...,
#          [ 1.9286,  1.4395,  1.3767,  ...,  1.3415, -1.4627, -1.4582],
#          [ 1.8385,  1.3104,  1.4771,  ...,  1.6018, -1.5601, -1.4801],
#          [ 1.8076,  1.5781,  1.4110,  ...,  1.4801, -1.5943, -1.6433]]])
# tensor([[[ 1.0821,  0.0488,  0.4473,  ..., -0.0181, -0.6887, -0.5817],
#          [ 0.6515,  0.6619, -0.1981,  ...,  0.7510, -0.1510, -0.8250],
#          [ 0.7821, -0.1332,  0.4674,  ...,  0.7510,  0.4063, -0.7217],
#          ...,
#          [ 1.4738,  1.4336,  1.5312,  ...,  1.4801, -1.5927, -1.5862],
#          [ 1.6573,  1.4030,  1.4981,  ...,  1.3415, -1.3947, -1.5536],
#          [ 1.7545,  1.4707,  1.3475,  ...,  1.6018, -1.6039, -1.4400]]])
# tensor([[[ 1.1460,  0.8337,  0.7224,  ..., -0.2197,  0.2594,  1.4719],
#          [ 0.2701,  0.5916,  0.5416,  ...,  0.6626,  0.4350,  1.0545],
#          [ 1.1818,  0.6125,  0.6304,  ...,  0.3157,  0.6383,  1.0030],
#          ...,
#          [ 1.5705,  1.5024,  1.6168,  ...,  1.2935,  1.5643,  1.8876],
#          [ 1.2715,  1.5813,  1.5833,  ...,  1.5649,  1.6912,  1.6658],
#          [ 1.5258,  1.7716,  1.5165,  ...,  1.2935,  1.1898,  1.7722]]])
# tensor([[[ 0.5840,  0.3130,  0.5406,  ...,  1.2707,  1.2772,  0.6940],
#          [ 0.5065, -0.4754,  0.2493,  ...,  1.0969,  1.2910,  0.9657],
#          [ 0.7506,  0.7751,  0.7151,  ...,  0.6194,  1.1438,  0.7039],
#          ...,
#          [ 1.2730,  1.4413,  1.3962,  ...,  1.5476,  1.7792,  1.4686],
#          [ 1.5990,  1.6579,  1.3608,  ...,  1.6618,  1.4547,  1.5546],
#          [ 1.4974,  1.3038,  1.5949,  ...,  1.7643,  1.6541,  1.4425]]])
# tensor([[[ 0.0331,  0.4074,  0.7047,  ...,  0.2614, -1.2298, -0.6569],
#          [ 0.6880,  0.3817,  0.8604,  ...,  0.2614, -0.9736, -1.1053],
#          [ 0.8142,  0.7373,  1.0881,  ...,  0.6244, -1.1970, -0.5816],
#          ...,
#          [ 1.5805,  1.5160,  1.6622,  ...,  1.4210, -1.6462, -1.4614],
#          [ 1.6453,  1.6365,  1.5541,  ...,  1.4210, -1.8988, -1.5394],
#          [ 1.2636,  1.4829,  1.6175,  ...,  1.5497, -1.6568, -1.4592]]])
# tensor([[[ 0.8122,  0.6376,  0.3010,  ...,  0.7510, -0.3635,  0.7669],
#          [ 0.6159,  1.0491, -0.1639,  ...,  0.7510,  0.2172,  0.4477],
#          [ 0.4718,  0.7116, -0.2057,  ...,  0.9887,  0.4325,  0.5003],
#          ...,
#          [ 1.3354,  1.4610,  1.5511,  ...,  1.7102,  1.3298,  1.3799],
#          [ 1.5394,  1.4769,  1.4695,  ...,  1.6018,  1.3429,  1.2872],
#          [ 1.5953,  1.5128,  1.6164,  ...,  1.4801,  1.5317,  1.4067]]])
# tensor([[[-0.1340,  0.4962,  0.0364,  ...,  0.4386,  0.7999,  1.3338],
#          [ 0.2134,  0.7345,  0.2616,  ..., -0.0181,  0.7062,  0.9202],
#          [ 0.6654,  0.5867, -0.1472,  ...,  0.4386,  0.7541,  1.1863],
#          ...,
#          [ 1.2939,  1.6087,  1.4921,  ...,  1.4801,  1.6411,  1.7898],
#          [ 1.6217,  1.6433,  1.2353,  ...,  1.7102,  1.5815,  1.8163],
#          [ 1.6624,  1.4952,  1.5848,  ...,  1.4801,  1.6696,  1.6984]]])
# tensor([[[ 1.0270,  0.8847, -0.0842,  ..., -0.2197, -0.7077, -0.6477],
#          [ 0.4005,  0.2661,  0.6275,  ...,  0.6626, -0.7607, -0.2382],
#          [ 0.9338,  0.8059,  0.4831,  ...,  0.3157, -0.3125, -0.2621],
#          ...,
#          [ 1.5806,  1.7321,  1.4208,  ...,  1.4384, -1.5779, -1.5926],
#          [ 1.6000,  1.5891,  1.5723,  ...,  1.5649, -1.8374, -1.4322],
#          [ 1.7302,  1.4876,  1.4454,  ...,  1.4384, -1.7739, -1.6579]]])
# tensor([[[ 0.9597, -0.0553,  1.0983,  ...,  1.0969, -1.0538, -0.3478],
#          [ 1.1523,  0.4951,  0.8930,  ...,  0.8863, -0.4340,  0.6294],
#          [ 0.7665,  0.6904,  0.9174,  ...,  1.0969, -1.1456, -0.4054],
#          ...,
#          [ 1.5903,  1.2067,  1.7189,  ...,  1.5476, -1.4335, -1.2053],
#          [ 1.6172,  1.6004,  1.5859,  ...,  1.4187, -1.6137, -1.5213],
#          [ 1.5383,  1.6839,  1.7173,  ...,  1.5476, -1.4848, -1.3745]]])
# tensor([[[ 0.4909,  0.6909,  0.7396,  ...,  0.8903,  0.7428,  0.7411],
#          [ 1.1576,  0.6496,  0.8635,  ...,  0.2614, -0.1533,  0.6863],
#          [ 0.9216,  0.0776,  0.2554,  ...,  1.1000,  0.5896,  0.7645],
#          ...,
#          [ 1.4157,  1.5883,  1.5167,  ...,  1.7659,  1.5019,  1.5903],
#          [ 1.3534,  1.5591,  1.4156,  ...,  1.6636,  1.5346,  1.5613],
#          [ 1.5742,  1.5585,  1.5173,  ...,  1.6636,  1.5453,  1.6522]]])
# tensor([[[ 1.1512,  1.1735,  0.3750,  ...,  0.8903,  0.4472,  0.3739],
#          [ 0.4782,  0.8566,  0.7672,  ...,  0.2614,  0.2740, -0.9717],
#          [ 0.7193,  1.1570,  0.2421,  ...,  1.1000,  0.9963,  0.4255],
#          ...,
#          [ 1.2920,  1.8039,  1.5604,  ...,  1.6636,  1.7905,  1.6156],
#          [ 1.7037,  1.7461,  1.4453,  ...,  1.5497,  1.8312,  1.7539],
#          [ 1.7840,  1.7083,  1.3640,  ...,  1.6636,  1.6575,  1.4259]]])
# tensor([[[ 0.4058,  0.7313,  0.1095,  ..., -0.2197, -0.2339, -1.0439],
#          [ 1.0634,  0.6769, -0.0342,  ...,  0.6626,  0.6055, -0.7914],
#          [ 0.7478,  0.5214,  0.5130,  ...,  0.6626,  0.4212, -0.7760],
#          ...,
#          [ 1.5130,  1.4027,  1.3145,  ...,  1.4384, -1.5328, -1.5327],
#          [ 1.7041,  1.5373,  1.5264,  ...,  1.4384, -1.6769, -1.6938],
#          [ 1.4656,  1.4724,  1.3314,  ...,  1.2935, -1.4457, -1.6754]]])
# tensor([[[-0.9168,  1.2313,  0.9186,  ...,  0.6244, -0.2339, -0.2997],
#          [ 0.4846,  0.9675,  0.5200,  ...,  0.6244, -0.0934, -0.7782],
#          [-0.8254,  0.9312,  0.4960,  ...,  0.6244,  0.3405, -0.1644],
#          ...,
#          [ 1.5106,  1.4106,  1.5624,  ...,  1.4210, -1.2913, -1.4911],
#          [ 1.5994,  1.7141,  1.6798,  ...,  1.4210, -1.4714, -1.6245],
#          [ 1.6223,  1.8557,  1.5792,  ...,  1.4210, -1.2605, -1.5469]]])
# tensor([[[ 0.7067,  2.2192,  1.1805,  ...,  0.6244, -1.5622, -0.0492],
#          [ 0.6683,  2.1326,  1.4140,  ...,  0.8903, -1.3715, -0.4387],
#          [ 1.1430,  2.1148,  1.0276,  ...,  1.2733, -1.4261, -0.1457],
#          ...,
#          [ 1.5844,  2.2520,  1.5928,  ...,  1.4210, -1.7983, -1.3069],
#          [ 1.4091,  2.1460,  1.6292,  ...,  1.4210, -1.6075, -1.1728],
#          [ 1.5112,  2.3396,  1.6254,  ...,  1.4210, -1.8858, -1.4838]]])
# tensor([[[ 1.1731,  0.6473,  1.2819,  ..., -0.0181, -0.4558, -1.0683],
#          [ 1.1430,  0.9443,  0.8548,  ...,  0.4386, -0.6750, -0.9310],
#          [ 0.8716,  0.6828,  0.7159,  ...,  0.7510, -1.0068, -0.3517],
#          ...,
#          [ 1.6562,  1.4717,  1.7807,  ...,  1.3415, -1.4800, -1.5838],
#          [ 1.9319,  1.3312,  1.6973,  ...,  1.3415, -1.3741, -1.5407],
#          [ 1.7469,  1.3715,  1.8101,  ...,  1.3415, -1.6095, -1.7992]]])
# tensor([[[ 0.6726,  0.6105,  0.2749,  ...,  1.2707,  1.1903,  0.6061],
#          [ 0.4795,  0.5488,  0.6614,  ...,  0.6194,  1.2201,  0.4440],
#          [ 0.9518,  0.8922, -0.2417,  ...,  1.0969,  1.1278,  0.2446],
#          ...,
#          [ 1.5900,  1.4724,  1.4377,  ...,  1.8572,  1.8442,  1.4863],
#          [ 1.4918,  1.4123,  1.3211,  ...,  1.5476,  1.7006,  1.4782],
#          [ 1.5088,  1.6403,  1.3093,  ...,  1.6618,  1.6446,  1.4911]]])
# tensor([[[-0.2497,  1.6377,  1.0050,  ...,  0.2614, -0.5111, -1.1211],
#          [ 0.0638,  1.4574,  0.9602,  ...,  0.8903, -1.2960, -1.0696],
#          [ 0.1660,  1.5544,  0.9823,  ...,  0.6244, -0.7972, -0.4970],
#          ...,
#          [ 1.1831,  1.7929,  1.6159,  ...,  1.2733, -1.3688, -1.5341],
#          [ 1.2345,  1.7173,  1.4844,  ...,  1.4210, -1.6164, -1.6067],
#          [ 1.3500,  1.7992,  1.5809,  ...,  1.4210, -1.6487, -1.4893]]])
# tensor([[[ 0.3258, -0.0143, -0.1640,  ...,  0.8903,  0.2887, -0.1641],
#          [ 0.6426, -0.1582,  0.5106,  ...,  0.2614,  0.0355, -0.1969],
#          [ 0.6820,  0.1590,  0.0073,  ...,  0.2614,  0.4596,  0.2076],
#          ...,
#          [ 0.9949,  1.4593,  1.4491,  ...,  1.4210,  1.6324,  1.4158],
#          [ 1.3922,  1.4892,  1.5142,  ...,  1.4210,  1.5301,  1.4817],
#          [ 1.2216,  1.5402,  1.5231,  ...,  1.6636,  1.6706,  1.3100]]])
# tensor([[[ 6.0515e-01,  5.4784e-01,  5.7327e-01,  ...,  4.3863e-01,
#            5.4322e-01,  5.6026e-01],
#          [ 7.1385e-01,  3.1142e-01,  7.4408e-02,  ...,  4.3863e-01,
#            5.7171e-01,  7.5994e-01],
#          [ 9.7594e-01, -2.5662e-04,  6.5518e-01,  ...,  7.5099e-01,
#            1.0354e+00,  8.0614e-01],
#          ...,
#          [ 1.4931e+00,  1.4844e+00,  1.5662e+00,  ...,  1.8081e+00,
#            1.5803e+00,  1.5063e+00],
#          [ 1.5474e+00,  1.6308e+00,  1.5077e+00,  ...,  1.3415e+00,
#            1.5596e+00,  1.5387e+00],
#          [ 1.5515e+00,  1.8310e+00,  1.4606e+00,  ...,  1.3415e+00,
#            1.4491e+00,  1.7180e+00]]])
# tensor([[[ 0.9221,  0.3190,  0.3715,  ..., -0.0181, -0.1117, -0.2149],
#          [ 0.8754,  0.5960,  0.3715,  ..., -0.8830,  0.7364, -0.3775],
#          [ 0.7206,  0.9950, -0.2836,  ..., -0.0181,  0.3658,  0.1417],
#          ...,
#          [ 1.5862,  1.4615,  1.4217,  ...,  1.1805,  1.4877,  1.4516],
#          [ 1.4480,  1.4676,  1.5125,  ...,  1.6018,  1.4179,  1.5431],
#          [ 1.5047,  1.5931,  1.4864,  ...,  1.4801,  1.4650,  1.4529]]])
# tensor([[[ 0.2656,  0.0033,  0.6493,  ...,  1.3818, -0.6520, -1.0469],
#          [ 0.0721,  0.7911,  0.5887,  ...,  1.3818, -0.5617, -0.8149],
#          [ 0.7634,  0.1921,  0.6552,  ...,  1.5152, -0.8591, -0.8996],
#          ...,
#          [ 1.2315,  1.2023,  1.4912,  ...,  1.7383, -1.3768, -1.5895],
#          [ 1.0682,  1.1571,  1.4757,  ...,  1.6329, -1.3194, -1.3134],
#          [ 1.5492,  1.3250,  1.1374,  ...,  1.6329, -1.4698, -1.3124]]])
# tensor([[[ 0.4564,  0.8311,  0.4010,  ...,  0.8863,  0.1740, -1.3557],
#          [ 0.9071,  1.1329,  0.6480,  ...,  0.6194,  0.9197, -0.9848],
#          [ 0.9597,  0.2420,  0.8079,  ...,  0.8863,  1.0688, -1.1718],
#          ...,
#          [ 1.4878,  1.5323,  1.4793,  ...,  1.4187, -1.4500, -1.6737],
#          [ 1.5300,  1.2825,  1.3596,  ...,  1.2707, -1.5486, -1.6612],
#          [ 1.3974,  1.3410,  1.5822,  ...,  1.4187, -1.2014, -1.6444]]])

# %%
df_train_0=df_train.copy()
df_train_0=Preprocessing.drop_sensors(df_train_0,[1,2,3,4,5]) 
df_train_0=Preprocessing.drop_units(df_train_0,[1,2,3,4,5])
# df_train_0.drop(df_train_0[df_train_0["Unit"].isin([1,2,3,4,5])].index,axis=0,inplace=True)
# df_train_0.reset_index(drop=True)

# %%
small_train_=AircraftDataset(df_train)
small_test_=AircraftDataset(small_test)

# %%
def feature_extration_from_his_unit_v1(data):# data为类AircraftDataset的一个实例
    input_dim=CFG.input_dim #11
    feature=np.zeros((len(data),3,input_dim))
    coefs=np.zeros((len(data),input_dim,3))
    for unit in range(len(data)):
        data_l=data[unit]["input"].numpy()
        timeseries_l=data[unit]["timeseries"].numpy()
        feature_l=np.zeros((3,input_dim))
        for sensor in range(data_l.shape[1]):
            coef=np.polyfit(timeseries_l.reshape(-1), data_l[:,sensor], 2)
            tau=timeseries_l[-1]
            feature_l[0][sensor]=np.polyval(coef, tau)*0.1
            feature_l[1][sensor]=(2*coef[0]*tau+coef[1])*10
            feature_l[2][sensor]=(2*coef[0])*1000
            coefs[unit][sensor]=coef
        feature[unit]=feature_l
    return feature,coefs

# %%
feature,coefs=feature_extration_from_his_unit_v1(small_train_)

# %%
feature[0][:,0]
# Out:
# array([0.16273807, 0.07992464, 0.03884303])

# %%
def get_sigma_m_j(data_m,timeseries_m,sensor_index_j):
    coef_m_j=np.polyfit(timeseries_m.reshape(-1),data_m[:,sensor_index_j],2)
    Phi_mj_Gamma_mj=np.polyval(coef_m_j,timeseries_m.reshape(-1))
    Y_mj=data_m[:,sensor_index_j]
    sigma_m_j_2=(Y_mj-Phi_mj_Gamma_mj).T@(Y_mj-Phi_mj_Gamma_mj).T/(len(timeseries_m)-1)
    return sigma_m_j_2

# %%
data_m=in_data[0]["input"].numpy()
timeseries_m=in_data[0]["timeseries"].numpy()
coef_m_j=np.polyfit(timeseries_m.reshape(-1),data_m[:,0],2)
Phi_mj_Gamma_mj=np.polyval(coef_m_j,timeseries_m.reshape(-1))
Y_mj=data_m[:,0]
sigma_m_j_2=(Y_mj-Phi_mj_Gamma_mj).T@(Y_mj-Phi_mj_Gamma_mj).T/(len(timeseries_m)-1)
sigma_m_j_2
# Out:
# 0.08294416733932455

# %%
features,coefs=feature_extration_from_his_unit_v1(small_train_)
n_units=len(coefs)
sigma_m_j_2=get_sigma_m_j(data_m,timeseries_m,0)
#for his_index in range(len(coefs)):
Phi_lj_Gamma_lj=np.polyval(coefs[0][0],timeseries_m.reshape(-1))
Y_mj=data_m[:,0]
w_l_j=np.exp((Y_mj-Phi_lj_Gamma_lj).T@(Y_mj-Phi_lj_Gamma_lj)/(-2*sigma_m_j_2))
w_l_j
# Out:
# 1.6774395072917635e-59

# %%
def get_fusion_weight_l_j(coefs,data_m,sensor_index_j,timeseries_m):
    n_units=len(coefs)
    sigma_m_j_2=get_sigma_m_j(data_m,timeseries_m,sensor_index_j)
    w_j=np.zeros((n_units,1))
    for his_index in range(n_units):
        Phi_lj_Gamma_lj=np.polyval(coefs[his_index][sensor_index_j],timeseries_m.reshape(-1))
        Y_mj=data_m[:,sensor_index_j]
        w_l_j=np.exp((Y_mj-Phi_lj_Gamma_lj).T@(Y_mj-Phi_lj_Gamma_lj)/(-2*sigma_m_j_2))
        w_j[his_index]=w_l_j
    return w_j/np.sum(w_j)
#get_fusion_weight_l_j(coefs,data_m,0,timeseries_m)

# %%
w_j=get_fusion_weight_l_j(coefs,data_m,0,timeseries_m)
features[:,:,0].T@w_j
# Out:
# array([[0.13976282],
#        [0.06522762],
#        [0.03255469]])

# %%
def feature_fusion_for_in_unit_v1(his_data,in_data):# data为类AircraftDataset的一个实例,in_data同理
    input_dim=CFG.input_dim
    feature_fusion=np.zeros((len(in_data),3,input_dim))
    features,coefs=feature_extration_from_his_unit_v1(his_data)#shape(len(data),3,11)
    for in_unit in range(len(in_data)):
        data_q=in_data[in_unit]["input"].numpy()
        timeseries_q=in_data[in_unit]["timeseries"].numpy()
        feature_l=np.zeros((3,input_dim))
        for sensor in range(input_dim):
            w_unit_sensor=np.zeros(len(his_data),dtype=np.float64)
            coef_q=np.polyfit(timeseries_q.reshape(-1),data_q[:,sensor],2)
            piancha=data_q[:,sensor]-np.polyval(coef_q,timeseries_q.reshape(-1))
            sigma_j_2=np.inner(piancha,piancha)/(len(timeseries_q)-1)
            for his_unit in range(len(his_data)):
                residual_sum_ij=0
                for time in range(len(timeseries_q)):
                    coef_ij=coefs[his_unit][sensor]
                    residual=(data_q[time][sensor]-np.polyval(coef_ij,time+1))**2
                    residual_sum_ij+=residual
                w_ij=np.exp(residual_sum_ij/(-2*sigma_j_2),dtype=np.float64)
                w_unit_sensor[his_unit]=w_ij
            feature_l[:,sensor]=features[:,:,sensor].T@w_unit_sensor/(np.sum(w_unit_sensor))
        feature_fusion[in_unit]=feature_l
    return feature_fusion

# %%
his_data=small_train_
in_data=small_test_
input_dim=CFG.input_dim
feature_fusion=np.zeros((len(in_data),3,input_dim))
features,coefs=feature_extration_from_his_unit_v1(his_data)#shape(len(data),3,11)
for in_unit in range(len(in_data)):
    data_q=in_data[in_unit]["input"].numpy()
    timeseries_q=in_data[in_unit]["timeseries"].numpy()
    feature_l=np.zeros((3,input_dim))
    for sensor in range(input_dim):
        w_unit_sensor=np.zeros(len(his_data),dtype=np.float64)
        coef_q=np.polyfit(timeseries_q.reshape(-1),data_q[:,sensor],2)
        piancha=data_q[:,sensor]-np.polyval(coef_q,timeseries_q.reshape(-1))
        sigma_j_2=np.inner(piancha,piancha)/(len(timeseries_q)-1)
        for his_unit in range(len(his_data)):
            residual_sum_ij=0
            for time in range(len(timeseries_q)):
                coef_ij=coefs[his_unit][sensor]
                residual=(data_q[time][sensor]-np.polyval(coef_ij,timeseries_q[time]))**2
                residual_sum_ij+=residual
            w_ij=np.exp(residual_sum_ij/(-2*sigma_j_2),dtype=np.float64)
            w_unit_sensor[his_unit]=w_ij
        feature_l[:,sensor]=features[:,:,sensor].T@w_unit_sensor/np.sum(w_unit_sensor)
    feature_fusion[in_unit]=feature_l
# Out:
# <ipython-input-17-5424f71d2ac4>:23: RuntimeWarning: invalid value encountered in true_divide
#   feature_l[:,sensor]=features[:,:,sensor].T@w_unit_sensor/np.sum(w_unit_sensor)

# %%
feature_l[:,0]
# Out:
# array([0.1283758 , 0.06306832, 0.02494708])

# %%
(features[:,:,sensor].T@w_unit_sensor).shape
# Out:
# (3,)

# %%
feature_fusion_for_in_unit_v1(small_train_,small_test_)
# Out:
# <ipython-input-16-a6126865b6c5>:22: RuntimeWarning: invalid value encountered in true_divide
#   feature_l[:,sensor]=features[:,:,sensor].T@w_unit_sensor/np.sum(w_unit_sensor)
# array([[[ 0.13763479,  0.13923567,  0.13911424,  0.14640727,
#           0.08213914,  0.0834616 ,  0.12957755,  0.14533371,
#           0.0780089 ,  0.07109846, -0.16310536,  0.15642606,
#           0.15619433,  0.14685867],
#         [ 0.06707627,  0.0842261 ,  0.10807268,  0.1593795 ,
#           0.07596223,  0.07714376,  0.0730068 ,  0.17464767,
#           0.07117152,  0.07666159, -0.06440086,  0.06550093,
#           0.09618395,  0.04165786],
#         [ 0.03485628,  0.03780652,  0.05262408,  0.0731948 ,
#           0.02607191,  0.03002288,  0.02146641,  0.08138291,
#           0.03276439,  0.03167581, -0.01968862,  0.02020852,
#           0.05355742,  0.01251198]],
#
#        [[ 0.16266506,  0.14933854,  0.14550494, -0.15689389,
#           0.09590367,  0.08541268,  0.14899794, -0.13454828,
#           0.08500012, -0.11632826,  0.14547834,         nan,
#          -0.15487742, -0.14652708],
#         [ 0.07976967,  0.05305564,  0.05043774, -0.06433615,
#           0.03787426,  0.0800155 ,  0.10901894, -0.08338913,
#           0.0254412 , -0.02872355,  0.08090862,         nan,
#          -0.11457362, -0.12780368],
#         [ 0.03874259,  0.0216621 ,  0.02150535, -0.02474569,
#           0.01383112,  0.03176711,  0.05524744, -0.04209121,
#           0.01044521, -0.01508466,  0.03258369,         nan,
#          -0.04679658, -0.05640936]],
#
#        [[ 0.12970432,  0.1345868 ,  0.1390011 ,         nan,
#           0.09000666,  0.09385985,  0.12957755,         nan,
#           0.09659536,  0.14203159, -0.17099024,  0.15642606,
#           0.15619423,  0.14685867],
#         [ 0.0507519 ,  0.05390848,  0.10862338,         nan,
#           0.06990906,  0.04626234,  0.0730068 ,         nan,
#           0.07315533,  0.06315927, -0.03523302,  0.06550093,
#           0.09618309,  0.04165786],
#         [ 0.02366191,  0.02111625,  0.05303915,         nan,
#           0.03803355,  0.02083479,  0.02146641,         nan,
#           0.03245634,  0.0198971 , -0.01099751,  0.02020852,
#           0.0535568 ,  0.01251198]],
#
#        [[ 0.16501177,  0.14060786,  0.17580368, -0.15689389,
#           0.13719344, -0.11604154,  0.1491949 , -0.15452249,
#           0.14569754,  0.12988801, -0.16310536,         nan,
#          -0.15312318,  0.09300032],
#         [ 0.06580491,  0.04063997,  0.03431155, -0.06433615,
#           0.16352128, -0.00398545,  0.05265349, -0.10477947,
#           0.09499295,  0.17893408, -0.06440086,         nan,
#          -0.0655342 ,  0.08028034],
#         [ 0.03029986,  0.01578616,  0.01434591, -0.02474569,
#           0.07869685, -0.00372056,  0.02317241, -0.03953266,
#           0.02800409,  0.09494068, -0.01968862,         nan,
#          -0.02337215,  0.04406252]],
#
#        [[ 0.15051007,  0.1363753 ,  0.14509819,  0.15194967,
#           0.09101444,  0.09298861,  0.15467023,  0.14533371,
#           0.09410115,  0.129888  , -0.16310536,  0.15642606,
#           0.1513238 ,  0.14433299],
#         [ 0.05816792,  0.05544623,  0.0652303 ,  0.11176262,
#           0.02464659,  0.11328734,  0.10430603,  0.17464767,
#           0.03002277,  0.17893407, -0.06440086,  0.06550093,
#           0.06550893,  0.12485997],
#         [ 0.02173494,  0.02228806,  0.01954842,  0.03158036,
#           0.01047051,  0.05541585,  0.04634813,  0.08138291,
#           0.01619901,  0.09494067, -0.01968862,  0.02020852,
#           0.0196858 ,  0.06558382]],
#
#        [[ 0.15108358,  0.17554186,  0.14459729,  0.06227895,
#                  nan,  0.15051905,  0.1514474 ,  0.08312457,
#                  nan,  0.07599917,  0.15729432,         nan,
#           0.15132372, -0.14651935],
#         [ 0.09102073,  0.052331  ,  0.04864606,  0.05474716,
#                  nan,  0.08382125,  0.10698376,  0.09221458,
#                  nan,  0.08253911,  0.08651738,         nan,
#           0.06550842, -0.12779697],
#         [ 0.04301189,  0.03246068,  0.02016883,  0.01361715,
#                  nan,  0.02421714,  0.05140445,  0.03653629,
#                  nan,  0.0370352 ,  0.03787559,         nan,
#           0.01968523, -0.05640612]],
#
#        [[ 0.16501177,  0.16195324,  0.15916757, -0.15689389,
#           0.09590248,  0.0834616 ,  0.14858415, -0.15753843,
#           0.08514419,         nan, -0.16310536,  0.16105307,
#          -0.15487742, -0.14012717],
#         [ 0.06580491,  0.04186074,  0.07740748, -0.06433615,
#           0.03787388,  0.07714376,  0.08135873, -0.05817137,
#           0.02551373,         nan, -0.06440086,  0.07658637,
#          -0.11457363, -0.06244835],
#         [ 0.03029986,  0.01897777,  0.04162364, -0.02474569,
#           0.01383055,  0.03002288,  0.04636947, -0.02409149,
#           0.01053629,         nan, -0.01968862,  0.0386369 ,
#          -0.04679658, -0.02829382]],
#
#        [[ 0.16501177,  0.13458674,  0.14662978, -0.16212785,
#           0.10281091, -0.11604154,  0.14858415, -0.15452939,
#           0.09410115,  0.07109846,  0.15611239,  0.14442675,
#           0.1513236 , -0.15986159],
#         [ 0.06580491,  0.05390843,  0.07149035, -0.08215048,
#           0.04009039, -0.00398545,  0.08135873, -0.10478531,
#           0.03002277,  0.07666159,  0.08425915,  0.05883498,
#           0.06550766, -0.05478565],
#         [ 0.03029986,  0.02111621,  0.02505213, -0.02876451,
#           0.01705404, -0.00372056,  0.04636947, -0.03953361,
#           0.01619901,  0.03167581,  0.0368421 ,  0.02487335,
#           0.01968439, -0.02243908]],
#
#        [[ 0.1283758 ,  0.13489024,  0.14662978, -0.12728177,
#           0.08198775,  0.15051905,  0.12957755, -0.14386206,
#           0.14569737, -0.11632826,  0.14547834,  0.15642606,
#          -0.15487742, -0.14010582],
#         [ 0.06306832,  0.05170847,  0.07149035, -0.06832215,
#           0.07571946,  0.08382125,  0.07300681, -0.09560966,
#           0.09499289, -0.02872355,  0.08090862,  0.06550093,
#          -0.11457363, -0.06228246],
#         [ 0.02494708,  0.02010015,  0.02505213, -0.02545378,
#           0.02600285,  0.02421714,  0.02146641, -0.03814362,
#           0.0280041 , -0.01508466,  0.03258369,  0.02020852,
#          -0.04679658, -0.02816181]]])

# %%
class AircraftFeature(Dataset):
    def __init__(self, feature):
        self.feature = feature
        self.xij=self.get_xij()
        
    def __len__(self):
        return self.feature.shape[0]
    
    def get_xij(self):
        xij=torch.zeros(len(self),self.feature.shape[1]*self.feature.shape[2],dtype=torch.float,requires_grad=False)
        for i in range(len(self)):
            xij[i]=torch.tensor(self.feature[i].transpose(1,0).flatten(),requires_grad=False).unsqueeze(0)
        return xij
            
    

    def __getitem__(self, idx):
        feature_l=self.feature[idx].transpose(1,0).flatten()
        return torch.tensor(feature_l,dtype=torch.float).unsqueeze(0)

# %%
class CustomModel(nn.Module):
    def __init__(self):
        super(CustomModel, self).__init__()
        #         self.cfg=cfg
        #         self.input_dim=cfg.input_dim
        #         self.hidden_size=cfg.hidden_size
        #         self.num_classes=cfg.num_classes

        self.mlp = nn.Sequential(
            nn.Linear(CFG.input_feature, CFG.hidden_size),
            nn.ReLU(),
        )
        # self.lstm1=nn.LSTM(CFG.hidden_size, CFG.hidden_size//2, dropout=0.1, batch_first=True, bidirectional=True)
        self.logits = nn.Sequential(
            nn.Linear(CFG.hidden_size, CFG.num_classes),
        )

    def forward(self, x):
        features = self.mlp(x)
        # features, _ = self.lstm1(features)
        pred = self.logits(features)
        return pred

# %%
def save_model_weights(model, filename, verbose=1, cp_folder=""):
    """
    Saves the weights of a PyTorch model.

    Args:
        model (torch model): Model to save the weights of.
        filename (str): Name of the checkpoint.
        verbose (int, optional): Whether to display infos. Defaults to 1.
        cp_folder (str, optional): Folder to save to. Defaults to "".
    """
    if verbose:
        print(f"\n -> Saving weights to {os.path.join(cp_folder, filename)}\n")
    torch.save(model.state_dict(), os.path.join(cp_folder, filename))

# %%
class CustomLoss(nn.Module):

    def __init__(self):
        self.kernal=CFG.kernel
        super(CustomLoss, self).__init__()
    
    def get_kernel(self,x_ij,x_0j):#100*1*33 and 1*1*33 tensor
        n_unit=len(x_ij)
        distance=np.zeros((n_unit))
        weights=np.zeros((n_unit))
        x_ij=x_ij.numpy()
        x_0j=x_0j.numpy()
        for i in range(n_unit):
            distance[i]=np.linalg.norm(x_ij[i]-x_0j)**2
        index=np.argsort(distance)[0:int(np.ceil(n_unit/2))]#可能可以加入无监督学习，先这样
        weights[index]=1
        return weights
        
        
        
            
        
    

    def get_loss_kernel(self, pred, target,x_ij,x_0j):  #pred is list of tensor, target is a tensor
        n_unit=len(pred)
        loss=torch.zeros(1, dtype=torch.float)
        weights=self.get_kernel(x_ij,x_0j)
        for idx in range(len(pred)):
            if self.kernal:
                loss_l=((pred[idx]-target[idx])**2*weights[idx]/2).squeeze(-1)
            else:
                loss_l=((pred[idx]-target[idx])**2/2).squeeze(-1)
            loss+=loss_l
        return loss/n_unit
            
        
    def forward(self, pred, target,x_ij,x_0j):
        custom_loss = self.get_loss_kernel(pred, target,x_ij,x_0j)

        return custom_loss

# %%
# 类和方法的实例化，创建训练和测试的数据集
model=CustomModel()
#初始化模型的参数
# pre_train=torch.load(".\\model_checkpoints\\pre_train.pt")
# model.load_state_dict(pre_train) 
for layer in model.modules():
    if isinstance(layer, nn.Linear):
        nn.init.xavier_uniform_(layer.weight.data, gain=nn.init.calculate_gain('relu'))

Air_train_dataset=AircraftDataset(small_train)
Air_test_dataset=AircraftDataset(small_test)
n_units=len(Air_train_dataset)
train_target=[]
for i in range(len(Air_train_dataset)):
    train_target.append(Air_train_dataset[i]["lifetime"])

#RUL
path = './Dataset 1/preprocessed data/RUL.csv'
RUL_frame = pd.read_csv(path, header=None)
RUL = RUL_frame.values[:, 0]
test_target=np.array([Air_test_dataset[i]["lifetime"].item()+RUL[i].item() for i in range(len(Air_test_dataset))])




Feature_train_dataset=AircraftFeature(feature_extration_from_his_unit_v1(Air_train_dataset)[0])
feature_in_unit=feature_fusion_for_in_unit_v1(Air_train_dataset,Air_test_dataset)
Feature_test_dataset=AircraftFeature(feature_in_unit)
xij_train=Feature_train_dataset.xij
xij_test=Feature_test_dataset.xij


train_loader = DataLoader(
        Feature_train_dataset,
        batch_size=CFG.batch_size,
        shuffle=False)#train_dataset
        
test_loader = DataLoader(
        Feature_test_dataset,
        batch_size=CFG.batch_size,
        shuffle=False)#test_dataset
        
loss_fuction=CustomLoss()#lossfuction
optimizer = getattr(torch.optim, CFG.optimizer)(model.parameters(), lr=CFG.lr)
# Out:
# <ipython-input-37-48280f64a1c4>:22: RuntimeWarning: invalid value encountered in true_divide
#   feature_l[:,sensor]=features[:,:,sensor].T@w_unit_sensor/sum(w_unit_sensor)

# %%
def fit_his_unit_in_unit_0(train_dataset_loader,#train_loader
                           train_target,
                           feature_train,#xij_train
                           feature_test,#xij_test
                          index):
    for epoch in range(CFG.epoches):
        train_pred=[]
        for data in train_loader:
            pred_l=model(data).squeeze(0)
            #pred_l=model(data["input"].to(CFG.device)).squeeze(0)
            train_pred.append(pred_l)
    
        loss=loss_fuction(train_pred,train_target,xij_train,xij_test[index])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        save_model_weights(model, f"model_in_unit_{index}.pt", cp_folder=".\\model_checkpoints")
        if CFG.print_training_process:
            print(f"epoch:{epoch}, loss:{loss.mean()}")
        if loss.mean()<1e-1:
            break

# %%
def pred_in_units(train_dataset_loader,#train_loader
                  test_dataset_loader,
                  train_target,
                           feature_train,#xij_train
                           feature_test#xij_test
                 ):
    pred=[]
    for idx,test_data in enumerate(test_dataset_loader):
        fit_his_unit_in_unit_0(train_dataset_loader,
                               train_target
                           ,feature_train
                           ,feature_test,
                          idx)
        pred_l=model(test_data)
        pred.append(pred_l.item())
    return np.array(pred)

# %%
np.abs(test_pred-test_target)
# Out:
# array([47.26831055,         nan,         nan,         nan, 32.91680908,
#                nan,         nan, 14.1317749 , 80.3572998 ])

# %%
test_pred=pred_in_units(train_loader,
            test_loader,
              train_target,
            xij_train,
            xij_test
                 )
err= (np.abs(test_pred - test_target)/test_target).mean(axis=0)
print(err)
# Out:
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:0, loss:30843.3125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:1, loss:30771.6328125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:2, loss:30700.5234375
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:3, loss:30630.875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:4, loss:30561.451171875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:570, loss:0.16438928246498108
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:571, loss:0.16332441568374634
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:572, loss:0.1622631549835205
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:573, loss:0.16121426224708557
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:574, loss:0.1601676195859909
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:575, loss:0.15912622213363647
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:576, loss:0.15809571743011475
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:577, loss:0.1570681929588318
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:578, loss:0.15604671835899353
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:579, loss:0.15504015982151031
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:580, loss:0.1540301889181137
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:581, loss:0.15302512049674988
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
# epoch:582, loss:0.15203087031841278
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:583, loss:0.15103736519813538
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:584, loss:0.15005452930927277
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:585, loss:0.1490793377161026
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:586, loss:0.14810208976268768
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:587, loss:0.14713488519191742
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:588, loss:0.1461736112833023
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:589, loss:0.14522068202495575
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:590, loss:0.144273042678833
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:591, loss:0.14333075284957886
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:592, loss:0.14238862693309784
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:593, loss:0.14145861566066742
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:594, loss:0.14052659273147583
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:595, loss:0.13960713148117065
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:596, loss:0.13868826627731323
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:597, loss:0.13778309524059296
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:598, loss:0.13688184320926666
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:599, loss:0.1359759420156479
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:600, loss:0.13508868217468262
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:601, loss:0.13419778645038605
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:602, loss:0.13331252336502075
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:603, loss:0.13243821263313293
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:604, loss:0.13156668841838837
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:605, loss:0.13070064783096313
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:606, loss:0.12983262538909912
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:607, loss:0.12898078560829163
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:608, loss:0.12812592089176178
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:609, loss:0.1272815316915512
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:610, loss:0.126436248421669
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:611, loss:0.12560084462165833
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:612, loss:0.12476906180381775
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:613, loss:0.12394896149635315
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:614, loss:0.12312489002943039
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:615, loss:0.12230971455574036
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:616, loss:0.12149935215711594
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:617, loss:0.12069389224052429
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:618, loss:0.11989184468984604
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:619, loss:0.11909488588571548
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:620, loss:0.11830535531044006
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:621, loss:0.11751838773488998
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:622, loss:0.11673392355442047
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:623, loss:0.11596115678548813
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:624, loss:0.11518578976392746
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:625, loss:0.11441691964864731
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:626, loss:0.11365571618080139
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:627, loss:0.11289695650339127
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:628, loss:0.11214706301689148
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:629, loss:0.11139547824859619
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:630, loss:0.11065220832824707
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:631, loss:0.109908826649189
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:632, loss:0.10917535424232483
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:633, loss:0.1084454357624054
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:634, loss:0.10771524161100388
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:635, loss:0.10699980705976486
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:636, loss:0.10628063231706619
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:637, loss:0.10556598752737045
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:638, loss:0.10485953837633133
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:639, loss:0.10415259748697281
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:640, loss:0.10345859080553055
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:641, loss:0.10276244580745697
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:642, loss:0.10207337886095047
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:643, loss:0.10138524323701859
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:644, loss:0.10069746524095535
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:645, loss:0.10002391785383224
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_7.pt
#
# epoch:646, loss:0.09934902936220169
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_8.pt
#
# epoch:0, loss:0.09868184477090836
# nan

# %%
fit_his_unit_in_unit_0(train_loader
                           ,xij_train
                           ,xij_test,
                          0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-442-533c17869b57> in <module>
# ----> 1 fit_his_unit_in_unit_0(train_loader
#       2                            ,xij_train
#       3                            ,xij_test,
#       4                           0)
#
# TypeError: fit_his_unit_in_unit_0() missing 1 required positional argument: 'index'

# %%
for epoch in range(CFG.epoches):
    train_pred=[]
    
    for data in train_loader:
        pred_l=model(data).squeeze(0)
        #pred_l=model(data["input"].to(CFG.device)).squeeze(0)
        train_pred.append(pred_l)
    
    loss=loss_fuction(train_pred,train_target,xij_train,xij_test[0])
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:465, loss:777.4323120117188
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:466, loss:776.7407836914062
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:467, loss:776.0504760742188
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:468, loss:775.3614501953125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:469, loss:774.6734619140625
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:470, loss:773.9866943359375
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:471, loss:773.3014526367188
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:472, loss:772.6171264648438
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:473, loss:771.9342041015625
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:474, loss:771.252197265625
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:475, loss:770.5717163085938
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:476, loss:769.8923950195312
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:477, loss:769.2141723632812
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:478, loss:768.537353515625
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:479, loss:767.8613891601562
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:480, loss:767.1868286132812
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:481, loss:766.513671875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:482, loss:765.8414916992188
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:483, loss:765.1705932617188
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:484, loss:764.500732421875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:485, loss:763.8321533203125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:486, loss:763.1649169921875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:487, loss:762.4987182617188
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:488, loss:761.8338012695312
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:489, loss:761.169921875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:490, loss:760.5073852539062
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:491, loss:759.8460693359375
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:492, loss:759.185791015625
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:493, loss:758.52685546875
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:494, loss:757.868896484375
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:495, loss:757.2122192382812
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:496, loss:756.5568237304688
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:497, loss:755.902587890625
#
# ...
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9837, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9838, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9839, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9840, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9841, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9842, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9843, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9844, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9845, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9846, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9847, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9848, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9849, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9850, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9851, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9852, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9853, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9854, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9855, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9856, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9857, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9858, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9859, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9860, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9861, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9862, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9863, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9864, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9865, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9866, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9867, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9868, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9869, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9870, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9871, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9872, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9873, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9874, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9875, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9876, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9877, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9878, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9879, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9880, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9881, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9882, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9883, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9884, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9885, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9886, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
# epoch:9887, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9888, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9889, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9890, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9891, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9892, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9893, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9894, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9895, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9896, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9897, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9898, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9899, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9900, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9901, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9902, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9903, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9904, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9905, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9906, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9907, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9908, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9909, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9910, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9911, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9912, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9913, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9914, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9915, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9916, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9917, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9918, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9919, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9920, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9921, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9922, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9923, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9924, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9925, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9926, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9927, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9928, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9929, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9930, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9931, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9932, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9933, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9934, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9935, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9936, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9937, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9938, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9939, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9940, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9941, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9942, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9943, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9944, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9945, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9946, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9947, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9948, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9949, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9950, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9951, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9952, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9953, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9954, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9955, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9956, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9957, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9958, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9959, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9960, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9961, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9962, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9963, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9964, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9965, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9966, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9967, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9968, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9969, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9970, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9971, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9972, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9973, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9974, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9975, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9976, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9977, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9978, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9979, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9980, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9981, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9982, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9983, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9984, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9985, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9986, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9987, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9988, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9989, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9990, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9991, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9992, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9993, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9994, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
# epoch:9995, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9996, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9997, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9998, loss:467.4444580078125
#
#  -> Saving weights to .\model_checkpoints\model_in_unit_0.pt
#
# epoch:9999, loss:467.4444580078125

# %%
train_pred,train_target
# Out:
# ([tensor([[192.0073]], grad_fn=<SqueezeBackward1>),
#   tensor([[287.0065]], grad_fn=<SqueezeBackward1>),
#   tensor([[281.8177]], grad_fn=<SqueezeBackward1>),
#   tensor([[337.8400]], grad_fn=<SqueezeBackward1>)],
#  [tensor(192),
#   tensor(287),
#   tensor(179),
#   tensor(189),
#   tensor(269),
#   tensor(188),
#   tensor(259),
#   tensor(150),
#   tensor(201)])

# %%
save_model_weights(model, f"pre_train.pt", cp_folder=".\\model_checkpoints")
# Out:
#  -> Saving weights to .\model_checkpoints\pre_train.pt

# %%
pre_train=torch.load(".\\model_checkpoints\\pre_train.pt")
model.load_state_dict(pre_train)
# Out:
# <All keys matched successfully>
